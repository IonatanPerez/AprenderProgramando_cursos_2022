# %%
print ("PUNTO 1")

materias = ["materia 1","materia 2","materia 3"]
print (materias)


print ("PUNTO 2")

materias.remove("materia 1")
print (materias)


print ("PUNTO 3")

materias.append("materia 4")
print (materias)


print("PUNTO 4")
print (materias[1])


print("PUNTO 5")

diccionario={"materia 1":"profesor 1","materia 2":"profesor 2","materia 3":"profesor 3"}
print (diccionario)


print ("PUNTO 6")

diccionario["materia 4"]="profesor 4"
print (diccionario)


print ("PUNTO 7")

diccionario.pop("materia 1")
print (diccionario)
# Out:
# PUNTO 1
# ['materia 1', 'materia 2', 'materia 3']
# PUNTO 2
# ['materia 2', 'materia 3']
# PUNTO 3
# ['materia 2', 'materia 3', 'materia 4']
# PUNTO 4
# materia 3
# PUNTO 5
# {'materia 1': 'profesor 1', 'materia 2': 'profesor 2', 'materia 3': 'profesor 3'}
# PUNTO 6
# {'materia 1': 'profesor 1', 'materia 2': 'profesor 2', 'materia 3': 'profesor 3', 'materia 4': 'profesor 4'}
# PUNTO 7
# {'materia 2': 'profesor 2', 'materia 3': 'profesor 3', 'materia 4': 'profesor 4'}

# %%
print ("PUNTO 1")

num1 = 15
num2 = 12
if num1 == num2:
  print ("son iguales")
else:
  print ("no son iguales")


print ("PUNTO 2")

clima = "no llueve"
if clima == "llueve":
  print ("podemos ir a la plaza")
else:
  print ("debemos quedarnos en casa")


print ("PUNTO 3")

lista = [10,20,30]
for num in lista:
  print (num+2)


print ("PUNTO 4")

materia = ["materia1","materia2","materia3","materia4","materia5"]
numero=1
for mat in materia:
  print (mat,numero)
  numero = numero +1


print ("PUNTO 5")

def dividir(num1,num2):
 return num1/num2
dividir(51,42)


print ("PUNTO 6")

def funcion(num1,num2):
  if num2==0:
    print ("no se puede realizar esta operacion")
  else:
    print (num1/num2)
funcion(320,32)


print ("PUNTO 7")

def lista_n(lista1,num):
  lista1.append(num)
numeros = [86,66]
lista_n(numeros,100)
print (numeros)
# Out:
# PUNTO 1
# no son iguales
# PUNTO 2
# debemos quedarnos en casa
# PUNTO 3
# 12
# 22
# 32
# PUNTO 4
# materia1 1
# materia2 2
# materia3 3
# materia4 4
# materia5 5
# PUNTO 5
# 25.5
# 21.0
# PUNTO 6
# 10.0
# PUNTO 7
# [86, 66, 100]

# %%
import pandas as pd
data = pd.read_csv("Dataset Proyecto Modulo 1 - Plan de vacunacion COVID-19.csv",  sep=",")


print ("PUNTO 1")

display (data.tail(3))


print ("PUNTO 2")

print (data.shape)


print ("PUNTO 3")

print (data.columns)


print ("PUNTO 4")

display (data["TIPO_EFECTOR"])


print ("PUNTO 5")

print ("mayor cantidad de dosis 1 dadas: "+ str(data["DOSIS_1"].max()))
print ("cantidad de dosis 1 dadas: "+ str(data["DOSIS_1"].sum()))
print ("mayor cantidad de dosis 2 dadas: "+ str(data["DOSIS_2"].max()))
print ("cantidad de dosis 2 dadas: "+ str(data["DOSIS_2"].sum()))


print ("PUNTO 6")


print ("PUNTO 7")
# Out:
# PUNTO 1
#       FECHA_ADMINISTRACION GRUPO_ETARIO GENERO     VACUNA TIPO_EFECTOR  \
# 27808   31JAN2022:00:00:00      61 a 70      F    Moderna      Público
# 27809   31JAN2022:00:00:00      61 a 70      F  Sinopharm      Público
# 27810   31JAN2022:00:00:00      61 a 70      F    Sputnik      Público
#
#        DOSIS_1  DOSIS_2  ID_CARGA  DOSIS_3
# 27808      0.0      3.0       NaN    484.0
# 27809      2.0     12.0       NaN      0.0
# 27810      1.0     13.0       NaN      0.0
# PUNTO 2
# (27811, 9)
# PUNTO 3
# Index(['FECHA_ADMINISTRACION', 'GRUPO_ETARIO', 'GENERO', 'VACUNA',
#        'TIPO_EFECTOR', 'DOSIS_1', 'DOSIS_2', 'ID_CARGA', 'DOSIS_3'],
#       dtype='object')
# PUNTO 4
# 0        Público nacional
# 1                 Privado
# 2                 Público
# 3        Público nacional
# 4                 Privado
#                ...
# 27806                 NaN
# 27807             Público
# 27808             Público
# 27809             Público
# 27810             Público
# ...

# %% [markdown]
# # Nueva sección
