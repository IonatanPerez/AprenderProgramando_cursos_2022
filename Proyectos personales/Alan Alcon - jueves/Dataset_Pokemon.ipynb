# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
data = pd.read_csv("pokemon.csv")
data.head(2)
# Out:
#       nombre  indice_guia  resistencia  ataque  defensa tipo_primario  \
# 0  Bulbasaur            1        128.0   118.0    111.0         Grass
# 1    Ivysaur            2        155.0   151.0    143.0         Grass
#
#   tipo_secundario  max_salud  tasa_captura  tasa_escape  Weight  Height  \
# 0          Poison      113.0           0.2         0.10     6.9     0.7
# 1          Poison      134.0           0.1         0.07    13.0     1.0
#
#   Legendario  generacion  fuerza_combate
# 0         No           1            1115
# 1         No           1            1699

# %%
data.columns
# Out:
# Index(['nombre', 'indice_guia', 'resistencia', 'ataque', 'defensa',
#        'tipo_primario', 'tipo_secundario', 'max_salud', 'tasa_captura',
#        'tasa_escape', 'Weight', 'Height', 'Legendario', 'generacion',
#        'fuerza_combate'],
#       dtype='object')

# %%
data.shape
# Out:
# (649, 15)

# %%
nombres_nuevos = {"Weight":"peso","Height":"altura"}
data.drop(columns=["indice_guia"],inplace=True)
data.rename(columns=nombres_nuevos,inplace=True)
data.head(2)
# Out:
#       nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 0  Bulbasaur        128.0   118.0    111.0         Grass          Poison
# 1    Ivysaur        155.0   151.0    143.0         Grass          Poison
#
#    max_salud  tasa_captura  tasa_escape  peso  altura Legendario  generacion  \
# 0      113.0           0.2         0.10   6.9     0.7         No           1
# 1      134.0           0.1         0.07  13.0     1.0         No           1
#
#    fuerza_combate
# 0            1115
# 1            1699

# %%
data.describe()
# Out:
#        resistencia      ataque     defensa   max_salud  tasa_captura  \
# count   644.000000  644.000000  644.000000  644.000000    644.000000
# mean    168.700311  161.083851  140.324534  144.714286      0.243137
# std      45.648859   56.703088   49.092150   36.012643      0.173944
# min       1.000000   17.000000   32.000000   12.000000      0.000000
# 25%     137.000000  118.000000   99.000000  120.000000      0.100000
# 50%     163.000000  159.000000  136.500000  140.000000      0.200000
# 75%     190.000000  204.250000  174.000000  162.000000      0.300000
# max     496.000000  345.000000  396.000000  403.000000      1.000000
#
#        tasa_escape        peso      altura  generacion  fuerza_combate
# count   644.000000  649.000000  645.000000  649.000000      649.000000
# mean      0.083789   57.493374    1.150589    3.052388     1918.006163
# std       0.055595   90.558634    1.039428    1.494960      901.856030
# ...

# %%
data.dtypes
# Out:
# nombre              object
# resistencia        float64
# ataque             float64
# defensa            float64
# tipo_primario       object
# tipo_secundario     object
# max_salud          float64
# tasa_captura       float64
# tasa_escape        float64
# peso               float64
# altura             float64
# Legendario          object
# generacion           int64
# fuerza_combate       int64
# dtype: object

# %%
data.isna().sum()
# Out:
# nombre             0
# resistencia        5
# ataque             5
# defensa            5
# tipo_primario      5
# tipo_secundario    5
# max_salud          5
# tasa_captura       5
# tasa_escape        5
# peso               0
# altura             4
# Legendario         1
# generacion         0
# fuerza_combate     0
# dtype: int64

# %%
data[data["ataque"].isna()]
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 175   Togetic          NaN     NaN      NaN           NaN             NaN
# 248     Lugia          NaN     NaN      NaN           NaN             NaN
# 345   Cradily          NaN     NaN      NaN           NaN             NaN
# 568  Garbodor          NaN     NaN      NaN           NaN             NaN
# 580    Swanna          NaN     NaN      NaN           NaN             NaN
#
#      max_salud  tasa_captura  tasa_escape   peso  altura Legendario  \
# 175        NaN           NaN          NaN    3.2    0.61         No
# 248        NaN           NaN          NaN  216.0    5.21         Sí
# 345        NaN           NaN          NaN   60.4    1.50         No
# 568        NaN           NaN          NaN  107.3    1.90         No
# 580        NaN           NaN          NaN   24.2    1.30         No
#
#      generacion  fuerza_combate
# 175           2            1708
# 248           2            3703
# ...

# %%
data.to_csv("Dataset Pokemon modificado.csv")

# %%
data_pokemon_modificado=pd.read_csv("Dataset Pokemon modificado.csv")
data_pokemon_modificado.head()
# Out:
#    Unnamed: 0      nombre  resistencia  ataque  defensa tipo_primario  \
# 0           0   Bulbasaur        128.0   118.0    111.0         Grass
# 1           1     Ivysaur        155.0   151.0    143.0         Grass
# 2           2    Venusaur        190.0   198.0    189.0         Grass
# 3           3  Charmander        118.0   116.0     93.0          Fire
# 4           4  Charmeleon        151.0   158.0    126.0          Fire
#
#   tipo_secundario  max_salud  tasa_captura  tasa_escape   peso  altura  \
# 0          Poison      113.0          0.20         0.10    6.9     0.7
# 1          Poison      134.0          0.10         0.07   13.0     1.0
# 2          Poison      162.0          0.05         0.05  100.0     2.0
# 3            None      105.0          0.20         0.10    8.5     0.6
# 4            None      131.0          0.10         0.07   19.0     1.1
#
#   Legendario  generacion  fuerza_combate
# 0         No           1            1115
# ...

# %%
data_pokemon_modificado.drop(columns=['Unnamed: 0'],inplace=True)

# %%
data_pokemon_modificado.head()
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 0   Bulbasaur        128.0   118.0    111.0         Grass          Poison
# 1     Ivysaur        155.0   151.0    143.0         Grass          Poison
# 2    Venusaur        190.0   198.0    189.0         Grass          Poison
# 3  Charmander        118.0   116.0     93.0          Fire            None
# 4  Charmeleon        151.0   158.0    126.0          Fire            None
#
#    max_salud  tasa_captura  tasa_escape   peso  altura Legendario  generacion  \
# 0      113.0          0.20         0.10    6.9     0.7         No           1
# 1      134.0          0.10         0.07   13.0     1.0         No           1
# 2      162.0          0.05         0.05  100.0     2.0         No           1
# 3      105.0          0.20         0.10    8.5     0.6         No           1
# 4      131.0          0.10         0.07   19.0     1.1         No           1
#
#    fuerza_combate
# 0            1115
# ...
