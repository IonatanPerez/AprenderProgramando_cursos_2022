# %% [markdown]
# Definir 2 variables con números (num1 y num2). Crear una estructura condicional donde si los dos números son iguales se imprima "los dos números son iguales" (if... else...)

# %%
num1 = 34
num2 = 25
if num1 == num2:
  print ("son iguales")
else:
  print ("no son iguales")
# Out:
# no son iguales

# %% [markdown]
# Crear una estructura condicional donde si "no llueve", "podemos ir a la plaza" y sino "debemos quedarnos en casa" (if... else...)

# %%
clima = "llueve"
if clima == "no llueve":
  print ("Podemos ir a la plaza a jugar")
else:
  print ("Debemos quedarnos en casa")
# Out:
# Debemos quedarnos en casa

# %% [markdown]
# Definir una lista con 3 números (puede ser la misma que antes). Crear una estructura iterativa donde se imprima cada número +2 (for... in...)

# %%
lista = [20,40,60]
for num in lista:
  print (num+2)
# Out:
# 22
# 42
# 62

# %% [markdown]
# Crear una lista con 5 materias de la escuela. Crear una estructura interativa que permita CONTAR la cantidad de elementos en la lista (for... in...)

# %%
materia = ["Quimica","Matematica","Sistema de Control","Economia","Taller"]
numero=1
for mat in materia:
  print (mat,numero)
  numero = numero +1
# Out:
# Quimica 1
# Matematica 2
# Sistema de Control 3
# Economia 4
# Taller 5

# %% [markdown]
# Crea una función que divida dos números que reciba como parámetros

# %%
def dividir(num1,num2):
 return num1/num2
dividir(69,36)
# Out:
# 1.9166666666666667

# %% [markdown]
# Crea una función que reciba 2 números e incluya un condicional donde si el segundo número es 0 imprima "no se puede realizar esta operación" y sino realice una división entre el primer y el segundo número.

# %%
def funcion(num1,num2):
  if num2==0:
    print ("no se puede realizar esta operacion")
  else:
    print (num1/num2)
funcion(598,54)
# Out:
# 11.074074074074074

# %% [markdown]
# Crear una función que dada una lista de números y un número (parámetros), agregue el número a la lista (def)

# %%
def lista_n(lista1,num):
  lista1.append(num)
numeros = [95,54]
lista_n(numeros,100)
print (numeros)
# Out:
# [95, 54, 100]
