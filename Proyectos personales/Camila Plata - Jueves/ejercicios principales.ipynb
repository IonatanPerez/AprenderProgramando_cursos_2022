# %% [markdown]
# Ejercicios Tipos de datos

# %%
#1.hacer una lista que contenga 3 materias:

lista_de_materias=["biologia", "quimica", "historia"]
lista_de_materias
# Out:
# ['biologia', 'quimica', 'historia']

# %%
#2.eliminar el primer registro de la lista:

del lista_de_materias[0]
lista_de_materias
# Out:
# ['quimica', 'historia']

# %%
#3.agregar una materia mas al final:
#corregido

lista_de_materias.append("ingles")
lista_de_materias
# Out:
# ['biologia', 'quimica', 'historia', 'ingles']

# %%
#4.seleccionar el segundo elemento de la lista:

lista_de_materias[1]
# Out:
# 'quimica'

# %%
#5.crear un diccionario con las materias y el nombre del profesor:

diccionario_materias = {"biologia": "rodriguez", "quimica": "salgado", "historia": "lafranconi", "ingles": "goñi"}
diccionario_materias
# Out:
# {'biologia': 'rodriguez',
#  'historia': 'lafranconi',
#  'ingles': 'goñi',
#  'quimica': 'salgado'}

# %%
#6.agregar una materia y un profesor:

diccionario_materias["matematica"]="chiodini"
diccionario_materias
# Out:
# {'biologia': 'rodriguez',
#  'historia': 'lafranconi',
#  'ingles': 'goñi',
#  'matematica': 'chiodini',
#  'quimica': 'salgado'}

# %%
#7.eliminar una materia y un profesor:

diccionario_materias.pop("historia", "lafranconi")
diccionario_materias
# Out:
# {'biologia': 'rodriguez',
#  'ingles': 'goñi',
#  'matematica': 'chiodini',
#  'quimica': 'salgado'}

# %% [markdown]
# Ejericicios estructuras de control

# %%
#1.definir 2 variables con números y crear una estructura condicional donde si los dos números son iguales se imprima "los dos números son iguales":

num1= 5
num2= 5
if num1==num2:
  print("son iguales")
else:
  print("son distintos")
# Out:
# son iguales

# %%
#2.crar una estructura condicional donde si "no llueve", "podemos ir a la plaza" y sino "debemos quedarnos en casa":

no_llueve= 1
llueve= 1
if no_llueve==llueve:
  print("podemos ir a la plaza")
else:
  print("debemos quedarnos en casa")
# Out:
# podemos ir a la plaza

# %%
#3.definir una lista con 3 numeros y crear una estructura iterativa donde se imprima cada numero +2 (for..in):

lista_numeros= [3, 7, 15]
for i in lista_numeros:
  print(i+2)
# Out:
# 5
# 9
# 17

# %%
#4.crear una lista con 5 materias y una estructura iterativa que permita contar la cantidad de elementos en la lista(for..in):
#corregido

lista_materias= ["civica", "fisica", "lengua", "proyecto", "algoritmos"]
print(len(lista_materias))
# Out:
# 5

# %%
#5.crear una funcion que divida 2 numeros que reciba como parametros:
def funcion_numeros(num1, num2):
  return num1/num2
funcion_numeros(350,50)
# Out:
# 7.0

# %%
#6.crear una funcion que reciba 2 numeros e incluya un condicional donde si el num2 es 0 se imprima "no se puede realizar esta operación" y sino realice una división entre num1 y num 2:

def funcion_num(num3, num4):
  if num3==0:
    print("No se puede realizar esta operacion")
  else:
    return num3/num4
funcion_num(0,50)
# Out:
# No se puede realizar esta operacion

# %%
#7.crear una funcion que dada una lista de numeros y un numero(parametros), agregue el numero a la lista(def):
#falta corregir

list_num= [3,5,9]
num5=7
list_num.append(num5)
list_num
# Out:
# [3, 5, 9, 7]

# %% [markdown]
# Ejercicios pandas 1: exploración

# %%
import pandas as pd
data = pd.read_csv("/content/dataset_total_vacunas.csv")
data
# Out:
#       FECHA_ADMINISTRACION GRUPO_ETARIO GENERO  \
# 0       01MAR2021:00:00:00   30 o menos      M
# 1       01MAR2021:00:00:00      31 a 40      F
# 2       01MAR2021:00:00:00      31 a 40      F
# 3       01MAR2021:00:00:00      31 a 40      F
# 4       01MAR2021:00:00:00      31 a 40      F
# ...                    ...          ...    ...
# 31476   20MAR2022:00:00:00      81 a 90      F
# 31477   20MAR2022:00:00:00      81 a 90      F
# 31478   20MAR2022:00:00:00      81 a 90      M
# 31479   20MAR2022:00:00:00      81 a 90      M
# 31480     20MAR2022:00:00:          NaN    NaN
#
#                                                   VACUNA      TIPO_EFECTOR  \
# 0                                                Sputnik  Público nacional
# 1                                            AstraZeneca           Privado
# 2                                            AstraZeneca           Público
# 3                                                Sputnik           Privado
# ...

# %%
#1.ver las ultimas 3 filas del dataset:

data.tail(3)
# Out:
#       FECHA_ADMINISTRACION GRUPO_ETARIO GENERO  \
# 31478   20MAR2022:00:00:00      81 a 90      M
# 31479   20MAR2022:00:00:00      81 a 90      M
# 31480     20MAR2022:00:00:          NaN    NaN
#
#                                                   VACUNA TIPO_EFECTOR  \
# 31478                                            Moderna      Público
# 31479  vacuna Coronavirus (PFIZER) 1ra - 2da dosis, v...      Público
# 31480                                                NaN          NaN
#
#        DOSIS_1  DOSIS_2  ID_CARGA  DOSIS_3
# 31478      0.0      1.0       NaN      0.0
# 31479      0.0      1.0       NaN      4.0
# 31480      NaN      NaN       NaN      NaN

# %%
#2.ver el tamaño del dataset:

data.size
# Out:
# 301419

# %%
#3.ver los nombres de las columnas:

data.columns
# Out:
# Index(['FECHA_ADMINISTRACION', 'GRUPO_ETARIO', 'GENERO', 'VACUNA',
#        'TIPO_EFECTOR', 'DOSIS_1', 'DOSIS_2', 'ID_CARGA', 'DOSIS_3'],
#       dtype='object')

# %%
#4.seleccionar la columna "TIPO_EFECTOR" y ver que valores toma esa columna y cuantos registros hay de cada uno:

data['TIPO_EFECTOR'].value_counts()
# Out:
# Público             25956
# Privado              5337
# Público nacional     2198
# Name: TIPO_EFECTOR, dtype: int64

# %%
#5.¿cual es el registro en el que se dieron mayor cantidad de vacunas DOSIS_1?¿cuantas vacunas se dieron?¿y de DOSIS_2?:

data_agrupada = data.groupby("FECHA_ADMINISTRACION")
data_agrupada["DOSIS_1"].max()
# Out:
# FECHA_ADMINISTRACION
# 01APR2021:00:00:00    2769.0
# 01APR2022:00:00:00       0.0
# 01AUG2021:00:00:00       9.0
# 01DEC2021:00:00:00     828.0
# 01FEB2021:00:00:00       1.0
#                        ...
# 31JUL2021:00:00:00     129.0
# 31MAR2021:00:00:00    2789.0
# 31MAR2022:00:00:00      66.0
# 31MAY2021:00:00:00    3806.0
# 31OCT2021:00:00:00    5695.0
# Name: DOSIS_1, Length: 496, dtype: float64

# %%
#kaggle - pag

# %%
#6.eliminar la columna "ID_CARGA":

del(data["ID_CARGA"])
data
# Out:
#       FECHA_ADMINISTRACION GRUPO_ETARIO GENERO  \
# 0       01MAR2021:00:00:00   30 o menos      M
# 1       01MAR2021:00:00:00      31 a 40      F
# 2       01MAR2021:00:00:00      31 a 40      F
# 3       01MAR2021:00:00:00      31 a 40      F
# 4       01MAR2021:00:00:00      31 a 40      F
# ...                    ...          ...    ...
# 31476   20MAR2022:00:00:00      81 a 90      F
# 31477   20MAR2022:00:00:00      81 a 90      F
# 31478   20MAR2022:00:00:00      81 a 90      M
# 31479   20MAR2022:00:00:00      81 a 90      M
# 31480     20MAR2022:00:00:          NaN    NaN
#
#                                                   VACUNA      TIPO_EFECTOR  \
# 0                                                Sputnik  Público nacional
# 1                                            AstraZeneca           Privado
# 2                                            AstraZeneca           Público
# 3                                                Sputnik           Privado
# ...

# %%
#7.cambiar los nombres de todas las columnas a minuscula:

data.rename(columns= {"FECHA_ADMINISTRACION": "fecha_administracion",	"GRUPO_ETARIO": "grupo_etario",	"GENERO": "genero",	
                      "VACUNA": "vacuna",	"TIPO_EFECTOR": "tipo_efector",	"DOSIS_1": "dosis_1",	"DOSIS_2": "dosis_2",	
                      "ID_CARGA": "id_carga",	"DOSIS_3": "dosis_3"}, inplace=True)
data
# Out:
#       fecha_administracion grupo_etario genero  \
# 0       01MAR2021:00:00:00   30 o menos      M
# 1       01MAR2021:00:00:00      31 a 40      F
# 2       01MAR2021:00:00:00      31 a 40      F
# 3       01MAR2021:00:00:00      31 a 40      F
# 4       01MAR2021:00:00:00      31 a 40      F
# ...                    ...          ...    ...
# 31476   20MAR2022:00:00:00      81 a 90      F
# 31477   20MAR2022:00:00:00      81 a 90      F
# 31478   20MAR2022:00:00:00      81 a 90      M
# 31479   20MAR2022:00:00:00      81 a 90      M
# 31480     20MAR2022:00:00:          NaN    NaN
#
#                                                   vacuna      tipo_efector  \
# 0                                                Sputnik  Público nacional
# 1                                            AstraZeneca           Privado
# 2                                            AstraZeneca           Público
# 3                                                Sputnik           Privado
# ...

# %% [markdown]
# Ejercicios pandas 2: filtrar y agrupar

# %%
#1.crear un nuevo dataframe solamente con las vacunas aplicadas en efectores publicos:

print(data["tipo_efector"])
mask_publico = data["tipo_efector"]=="Público"  
mask_publico
# Out:
# 0        Público nacional
# 1                 Privado
# 2                 Público
# 3                 Privado
# 4                 Público
#                ...
# 31476             Público
# 31477             Público
# 31478             Público
# 31479             Público
# 31480                 NaN
# Name: tipo_efector, Length: 31481, dtype: object
# 0        False
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 31476     True
# 31477     True
# 31478     True
# 31479     True
# 31480    False
# Name: tipo_efector, Length: 31481, dtype: bool

# %%
#2.crear un nuevo dataframe solamente con las vacunas aplicadas de entre 41 a 50 años:

print(data["grupo_etario"])
mask_edad = data["grupo_etario"]== "81 a 90"
mask_edad

# %%
#3.calcular cuantas vacunas DOSIS_1 "Sinopharm" se dieron en efectores publicos y hacer 2 con filtros, debe usarse el signo "&" y colocar cada uno entre parentesis [(flitro1)&(filtro2)]:

# %%
#4. calcular cuantas vacunas "sputik" DOSIS_2 se dieron a mujeres:

# %%
#5.generar un dataframe con la cantidad de vacunas DOSIS_1 que se dieron para mujeres y generar otro dataframe para hombres, usar groupby:

# %%
#6.generar un dataframe que tenga la cantidad de vacunas DOSIS_1 aplicadas a mujeres y hombres de cada tipo de vacuna, usar groupby:

# %%
#7.calcular cuántas vacunas de DOSIS_1 y cuantas vacunas de DOSIS_2 se dieron en cada efector, y en total (sumadas las dos):
