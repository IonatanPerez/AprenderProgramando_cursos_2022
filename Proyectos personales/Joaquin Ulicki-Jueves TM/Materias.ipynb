# %% [markdown]
# Ejercicios Tipos de datos
# Hacer una lista que contenga 3 materias de la escuela

# %%
materias = ["Sistemas de Control","Redes","Taller"]
print (materias)
# Out:
# ['Sistemas de Control', 'Redes', 'Taller']

# %% [markdown]
# Eliminar el primer registro de la lista

# %%
materias.remove("Sistemas de Control")
print (materias)
# Out:
# ['Redes', 'Taller']

# %% [markdown]
# Agregar una materia más al final

# %%
materias.append("Economia")
print (materias)
# Out:
# ['Redes', 'Taller', 'Economia']

# %% [markdown]
# Seleccionar el segundo elemento de la lista

# %%
print (materias[1])
# Out:
# Taller

# %% [markdown]
# Crear un diccionario con las materias y el nombre del/la profesor/a

# %%
diccionario={"Redes":"Jorge Galbiati","Taller":"Pablo Loto","Economia":"Liliana chiponi"}
print (diccionario)
# Out:
# {'Redes': 'Jorge Galbiati', 'Taller': 'Pablo Loto', 'Economia': 'Liliana chiponi'}

# %% [markdown]
# Agregar una materia y un/a profesora/

# %%
diccionario["Sistemas embebidos"]="Daniel Di Lella"
print (diccionario)
# Out:
# {'Redes': 'Jorge Galbiati', 'Taller': 'Pablo Loto', 'Economia': 'Liliana chiponi', 'Sistemas embebidos': 'Daniel Di Lella'}

# %% [markdown]
# Eliminar una materia y un/a profesor/a

# %%
diccionario.pop("Taller")
print(diccionario)
# Out:
# {'Redes': 'Jorge Galbiati', 'Economia': 'Liliana chiponi', 'Sistemas embebidos': 'Daniel Di Lella'}
