# %% [markdown]
# # Ionatan Perez
#
# Esta es una notebook con los ejercicios que tenemos para hacer en el curso. Este es el ejemplo del profe.

# %% [markdown]
# # Semanas 1 y 2
#
# Clases del 11 al 22 de abril.

# %%
# Ejercicio 1

materias = ["Matematicas","Termodinamica","Ingles"]
print (materias)
# Out:
# ['Matematicas', 'Termodinamica', 'Ingles']

# %%
# Esto es para borrar
