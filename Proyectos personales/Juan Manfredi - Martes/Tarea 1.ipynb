# %% [markdown]
# #Juan Manfredi
# Tengo 17 años, voy a la Escuela tecnica 29
#
# ![yo](https://lh3.googleusercontent.com/ogw/ADea4I4hwF-ghQAod-0zu7XmqQGtbq3jWbSwwXFUEkkj=s32-c-mo)
#
# ## Mis pasatiempos
# - Jugar a la pc
# - Juntarme con mis amigos
# - Dormir

# %% [markdown]
# #Codigo

# %%
print(3+7)
print(3-7)
print("hola")
# Out:
# 10
# -4
# hola

# %%
"juan "*100
# Out:
# 'juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan juan '

# %%
(250*15)
# Out:
# 3750

# %%
type (250*15)
# Out:
# int
