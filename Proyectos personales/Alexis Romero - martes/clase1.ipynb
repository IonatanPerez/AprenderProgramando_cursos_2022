# %% [markdown]
# #Presentacion
#
# ####Nombre
# * Alexis
#
# ####Apellido
# * Romero
#
# ####Edad
# * 18
#
# ####Face Revealed
#  ![aqui](https://gluc.mx/u/fotografias/m/2020/8/20/f850x638-32020_109509_4836).
#
#
# ####Tiempolibre
#
# - juego a la compu
# - estudiar
# - jugar a la compu x2
#
# ####Nose que mas poner
#
# ![xdd](https://c.tenor.com/tIkZOxK_adAAAAAC/crab-rave.gif)

# %% [markdown]
# #Codigos
#
# Basicos

# %%
hola= ("creo que si")
print (hola)
# Out:
# creo que si

# %%
"hola" * 3
# Out:
# 'holaholahola'

# %%
type ("a")
# Out:
# str

# %%
resultado = int ("2")
type (resultado)
# Out:
# int

# %%
type (print)
# Out:
# builtin_function_or_method

# %%
def saludo():
  print ("hola, como andas?")

# %%
saludo()
# Out:
# hola como andas?

# %%
def saludo_personalizado(nombre):
  print("hola "+ nombre + "como andas?")

# %%
saludo_personalizado("Lautaro")
# Out:
# holaLautarocomo andas?

# %% [markdown]
# #Actividad 1

# %%
print ("alexis "*100)
# Out:
# alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis alexis

# %% [markdown]
# ##Actividad 2

# %%
resultado= 15 * 250

# %%
print (f"la cantidad de dinero total que reunieron fue de", resultado,"$")
# Out:
# la cantidad de dinero total que reunieron fue de 3750 $

# %%
type (resultado)
# Out:
# int
