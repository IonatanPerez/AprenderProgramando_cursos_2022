# %%
suma= 5+4
print (suma)
# Out:
# 9

# %%
resta= 9-4
print(resta)
# Out:
# 5

# %%
multiplicacion= 5*4
print(multiplicacion)
# Out:
# 20

# %%
division= 10/5
print(division)
# Out:
# 2.0

# %%
grupo1= ["banana","manzana","naranja"]
grupo2= ["tomate","lechuga","batata"]
grupo3=["papa","perejil","uva"]
print(grupo2)
grupo2.pop()
print(grupo2)
print(grupo1)
grupo1.pop()
print(grupo1)
# Out:
# ['tomate', 'lechuga', 'batata']
# ['tomate', 'lechuga']
# ['banana', 'manzana', 'naranja']
# ['banana', 'manzana']

# %%
todos_con_todos= [grupo1,grupo2,grupo3]
print(todos_con_todos)
# Out:
# [['banana', 'manzana'], ['tomate', 'lechuga'], ['papa', 'perejil', 'uva']]

# %%
paises={
    "francia":"paris",
    "españa":"madrid",
    "japon":"tokio",
}
print(paises)
paises["argentina"]="buenos aires"
print(paises)
# Out:
# {'francia': 'paris', 'españa': 'madrid', 'japon': 'tokio'}
# {'francia': 'paris', 'españa': 'madrid', 'japon': 'tokio', 'argentina': 'buenos aires'}
