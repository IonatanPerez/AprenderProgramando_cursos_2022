# %% [markdown]
# # Sebastian Zacariaz
#
# Esto es una notebook con los ejercicios que tenemos para hacer en el curso

# %% [markdown]
# # Semana 1 y 2
#
# Clases del 12 al 19 de Abril

# %%
# Ejercicio 1
materias = ["Matematicas","Hidraulica","Termodinamica"]
print(materias)
# Out:
# ['Matematicas', 'Hidraulica', 'Termodinamica']

# %% [markdown]
# # TAREA
#
# ## Hacer en una notebook nueva los siguientes ejercicios:
#
# 1. Crea dos variables con valores enteros y luego imprime los resultados de su suma, resta, multiplicación y división.
#
#
# 2. Crea dos listas con 3 nombres cada una llamadas grupo1 y grupo2.
#
#
# 3. Crea una tercera lista llamada grupo3 con los últimos nombres de cada una de las listas grupo1 y grupo2 y elimina esos nombres de las listas originales.
#
#
# 4. Crea una lista llamada todos con todos los nombres de las listas.
#
#
# 5. Crea un diccionario que tenga 3 pares de clave valor con países y capitales.
#
#
# 6. Hace un print de los nombres de lo países.
#
#
# 7. Mostrá los nombres de las capitales.
#
#
# 8. Agrega una par de país-capital.

# %% [markdown]
# #Punto 1

# %%
mi_variable1= 2

# %%
mi_variable2= 3

# %%
print(mi_variable1 + mi_variable2)
# Out:
# 5

# %%
print(3+2)
print(3*2)
print(3-2)
print(3/2)
# Out:
# 5
# 6
# 1
# 1.5

# %% [markdown]
# # Punto 2

# %%
grupo1= ["Sebastian","Jesus","Facundo"]
grupo2= ["Melina","Antonio","Juan"]
print(grupo1)
print(grupo2)
# Out:
# ['Sebastian', 'Jesus', 'Facundo']
# ['Melina', 'Antonio', 'Juan']

# %%
type(grupo1)
type(grupo2)
# Out:
# list

# %% [markdown]
# #Punto 3

# %%
print(grupo1)
grupo1.remove("Facundo")
print(grupo1)

print(grupo2)
grupo2.remove("Juan")
print(grupo2)
# Out:
# ['Sebastian', 'Jesus', 'Facundo']
# ['Sebastian', 'Jesus']
# ['Melina', 'Antonio', 'Juan']
# ['Melina', 'Antonio']

# %% [markdown]
# #Punto 4

# %%
todos= ["Sebastian","Jesus","Facundo","Melina","Antonio","Juan"]
print(todos)
# Out:
# ['Sebastian', 'Jesus', 'Facundo', 'Melina', 'Antonio', 'Juan']

# %% [markdown]
# # Punto 5, 6, 7 y 8

# %%
Diccionario={"País": ["Mexico","Argentina","Colombia"], "Capital":["Ciudad de Mexico","Buenos Aires","Bogotá"]}
print(Diccionario["País"])
print(Diccionario["Capital"])
Diccionario["España"]= "Madrid"
print(Diccionario)
# Out:
# ['Mexico', 'Argentina', 'Colombia']
# ['Ciudad de Mexico', 'Buenos Aires', 'Bogotá']
# {'País': ['Mexico', 'Argentina', 'Colombia'], 'Capital': ['Ciudad de Mexico', 'Buenos Aires', 'Bogotá'], 'España': 'Madrid'}

# %% [markdown]
# # Optativos
#
#
# 1) Armar una lista con 6 ciudades
#
#
# 2) Seleccionar la segunda ciudad
#
#
# 3) Eliminar la última ciudad
#
#
# 4) Reemplazar la primer ciudad con otra
#
#
# 5) Agregar una ciudad al final
#
#
# 6) Armar un diccionario que tenga 3 duplas de Provincia y Ciudad (ej: "Provincia de Buenos Aires: La Plata"
#
#
# 7) Eliminar el último registro (dupla Ciudad-Provincia)
#
#
# 8) Ver todas las claves (keys)

# %%
# PUNTO 1

ciudades = ["Mendoza", "Buenos Aires", "Corrientes", "San Salvador de Jujuy", "Cordoba", "San Miguel de Tucumán"]

# %%
#Punto 2
segundaciudad = ciudades[1:2]
print(segundaciudad)
# Out:
# ['Buenos Aires']

# %%
#Punto 3
ciudades.pop()
# Out:
# 'San Miguel de Tucumán'

# %%
#Punto 4

ciudades[0]= "Posadas"
print(ciudades)
# Out:
# ['Posadas', 'Buenos Aires', 'Corrientes', 'San Salvador de Jujuy', 'Cordoba']

# %%
#Punto 6
diccionario = {"Provincia de Cordoba": "La Falda", "Provincia de Buenos Aires": "Avellaneda", "Provincia de Mendoza": "San Rafael"}

# %%
#Punto 7 
diccionario.popitem()
# Out:
# ('Provincia de Mendoza', 'San Rafael')

# %%
#Punto 8
print(diccionario.keys())
# Out:
# dict_keys(['Provincia de Cordoba', 'Provincia de Buenos Aires'])
