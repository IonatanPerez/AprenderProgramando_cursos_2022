# %% [markdown]
# Crea dos variables con valores enteros y luego imprime los resultados de su suma, resta, multiplicación y división.

# %%
n1=3
n2=4
print(n1+n2)
print(n1-n2)
print(n1*n2)
print(n1/n2)
# Out:
# 7
# -1
# 12
# 0.75

# %% [markdown]
# Crea dos listas con 3 nombres cada una llamadas grupo1 y grupo2.

# %%
grupo1=["selene ","sol "," marcos"]
grupo2=["sebastian ","erica "," lucas"]

print(grupo1+grupo2)
# Out:
# ['selene ', 'sol ', ' marcos', 'sebastian ', 'erica ', ' lucas']

# %% [markdown]
# Crea una tercera lista llamada grupo3 con los últimos nombres de cada una de las listas grupo1 y grupo2 y elimina esos nombres de las listas originales.

# %%
nombre1 = grupo1.pop()
nombre2 = grupo2.pop()
grupo3=(nombre1+nombre2)
print(grupo3)

# %% [markdown]
# Crea una lista llamada todos con todos los nombres de las listas.

# %%
TODOS=(grupo1+grupo2)
print(TODOS)
# Out:
# ['selene ', 'sol ', 'sebastian ', 'erica ']

# %% [markdown]
# Crea un diccionario que tenga 3 pares de clave valor con países y capitales.

# %%
Pais= {
  "Argentina": "Buenos Aires",
  "Canada": "Ottawa",
  "francia": "Paris"
}

# %% [markdown]
# Hace un print de los nombres de lo países.

# %%
x = Pais.keys()

print(x)
# Out:
# dict_keys(['Argentina', 'Canada', 'francia'])

# %% [markdown]
# Mostrá los nombres de las capitales

# %%
capital =  Pais.values()
Pais["Argentina"] 

print(capital)
# Out:
# dict_values(['Buenos Aires', 'Ottawa', 'Paris'])

# %% [markdown]
# Agrega una par de país-capital

# %%
#agregar par clave-valor
Pais["Costa Rica"]="San Jose"
print(Pais)
# Out:
# {'Argentina': 'Buenos Aires', 'Canada': 'Ottawa', 'francia': 'Paris', 'Costa Rica': 'San Jose'}
