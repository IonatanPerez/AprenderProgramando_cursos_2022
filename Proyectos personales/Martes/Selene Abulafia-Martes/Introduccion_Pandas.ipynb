# %%
import pandas as pd

# %%
from google.colab import files
import io

# %%
filesUploaded = files.upload()
# Out:
#      <input type="file" id="files-723c4332-4f06-43cd-8292-ca2790a9d56f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-723c4332-4f06-43cd-8292-ca2790a9d56f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving calidad-de-aire-2019.csv to calidad-de-aire-2019.csv

# %%
import pandas as pd

# %%
data = pd.read_csv("calidad-de-aire-2019.csv")

# %%
type (data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ¿Cuántas columnas tiene el Dataframe?

# %%
data.shape
# Out:
# (2868, 11)

# %% [markdown]
# Seleccionar únicamente la columna "encuentro_tematica?

# %%
data.columns
# Out:
# Index(['fecha', 'hora', 'co_centenario', 'no2_centenario', 'pm10_centenario',
#        'co_cordoba', 'no2_cordoba', 'pm10_cordoba', 'co_la_boca',
#        'no2_la_boca', 'pm10_la_boca'],
#       dtype='object')

# %%
data["co_centenario"].unique()
# Out:
# array(['0.46', '0.47', '0.48', '0.42', '0.40', '0.38', '0.37', '0.36',
#        '0.39', '0.44', '0.49', '0.50', '0.51', '0.45', '0.41', '0.43',
#        '0.52', '0.53', '0.54', '0.55', '0.31', '0.24', '0.18', '0.13',
#        '0.09', '0.06', '0.05', '0.08', '0.10', '0.15', '0.17', '0.19',
#        '0.21', '0.22', '0.23', '0.26', '0.27', '0.25', '0.14', '0.29',
#        '0.32', '0.34', '0.35', '0.33', '0.30', '0.56', '0.60', '0.63',
#        '0.66', '0.64', '0.61', '0.58', '0.28', '0.57', '0.59', '0.62',
#        '0.69', '0.71', '0.72', '0.70', '0.67', '0.68', '0.65', '0.73',
#        's/d', '0.20', '0.12', '0.07', '0.78', '0.83', '0.87', '0.89',
#        '0.90', '0.86', '0.80', '0.75', '0.76', '0.16', '0.79', '0.85',
#        '0.88', '0.11', '0.81', '0.93', '0.94', '0.77', '0.82', '0.84',
#        '0.91', '0.95', '0.96', '0.92', '0.74', '1.02', '1.19', '1.28',
#        '1.32', '1.31', '1.21', '1.08', '0.97', '1.04', '1.05', '0.99'],
#       dtype=object)

# %% [markdown]
# Ver los últimos 5 registros

# %%
data
# Out:
#            fecha  hora co_centenario no2_centenario pm10_centenario  \
# 0     2019-01-01     1          0.46              7              19
# 1     2019-01-01     2          0.47              9              19
# 2     2019-01-01     3          0.48             11              19
# 3     2019-01-01     4          0.48             16              19
# 4     2019-01-01     5          0.46             10              19
# ...          ...   ...           ...            ...             ...
# 2863  2019-04-30     8          0.39             24              24
# 2864  2019-04-30     9          0.46             25              24
# 2865  2019-04-30    10          0.54             26              25
# 2866  2019-04-30    11          0.64             23              26
# 2867  2019-04-30    12          0.68             17              26
#
#      co_cordoba no2_cordoba pm10_cordoba co_la_boca no2_la_boca pm10_la_boca
# ...

# %% [markdown]
# ¿Cuántos participantes totales hubo?

# %%
display (data["co_centenario"])
# Out:
# 0       0.46
# 1       0.47
# 2       0.48
# 3       0.48
# 4       0.46
#         ...
# 2863    0.39
# 2864    0.46
# 2865    0.54
# 2866    0.64
# 2867    0.68
# Name: co_centenario, Length: 2868, dtype: object

# %% [markdown]
# ¿Cuáles son los posibles destinatarios?

# %% [markdown]
# Completemos el archivo Metadata con la información de cada columna del dataset.
