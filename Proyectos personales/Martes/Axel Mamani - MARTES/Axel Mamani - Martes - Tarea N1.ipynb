# %%
i# Ejercicio Nro.: 1
print("Axel "*100)
# Out:
# Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel Axel

# %%
# Ejercicio Nro.: 2
Amigos = int(15)
Dinero = int(250)
Cant =  Amigos*Dinero
print("Son " + str(Amigos) + " amigos con " + str(Dinero) + " pesos cada uno.")
print("La suma de todo el dinero de todos es: ") 
print(Cant)

print("// En total reunieron 3750 pesos entre los 15 amigos, siendo un dato tipo entero(Int).")
# Out:
# Son 15 amigos con 250 pesos cada uno.
# La suma de todo el dinero de todos es:
# 3750
# // En total reunieron 3750 pesos entre los 15 amigos, siendo un dato tipo entero(Int).
