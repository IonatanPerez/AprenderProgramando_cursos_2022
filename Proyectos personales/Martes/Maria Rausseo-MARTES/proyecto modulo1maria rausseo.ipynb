# %% [markdown]
# # Proyecto Módulo 1
# Esta Notebook es una guía de ejercicios para ir realizando a lo largo del primer módulo que servirá para practicar la escritura del código e ir viendo las aplicaciones.
#
# # Ejercicios Tipos de datos
# Hacer una lista que contenga 3 materias de la escuela
#
# Eliminar el primer registro de la lista
#
# Agregar una materia más al final
#
# Seleccionar el segundo elemento de la lista
#
# Crear un diccionario con las materias y el nombre del/la profesor/a
#
# Agregar una materia y un/a profesora/
#
# Eliminar una materia y un/a profesor/a
#
# # Ejericicios estructuras de control
# Definir 2 variables con números (num1 y num2). Crear una estructura condicional donde si los dos números son iguales se imprima "los dos números son iguales" (if... else...)
#
# Crear una estructura condicional donde si "no llueve", "podemos ir a la plaza" y sino "debemos quedarnos en casa" (if... else...)
#
# Definir una lista con 3 números (puede ser la misma que antes). Crear una estructura iterativa donde se imprima cada número +2 (for... in...)
#
# Crear una lista con 5 materias de la escuela. Crear una estructura interativa que permita CONTAR la cantidad de elementos en la lista (for... in...)
#
# Crea una función que divida dos números que reciba como parámetros
#
# Crea una función que reciba 2 números e incluya un condicional donde si el segundo número es 0 imprima "no se puede realizar esta operación" y sino realice una división entre el primer y el segundo número.
#
# Crear una función que dada una lista de números y un número (parámetros), agregue el número a la lista (def)
#
# # Ejercicios Dataset pandas
# Para estos ejercicios utilizaremos un dataset extraído de https://data.buenosaires.gob.ar/dataset/plan-de-vacunacion-covid-19 con la información de las vacunas dadas en la Ciudad de Buenos Aires entre el 8/3/2021 hasta el 31/01/22
#
# import pandas as pd
# from google.colab import drive
# drive.mount('/content/drive')
# Mounted at /content/drive
# data = pd.read_csv("/content/drive/MyDrive/Aprender Programando/2022/Guías y Recursos - Trayectos 2021/Recursos/Modulos 1 y 2. Presentación CABA/Ciencia de datos/2022/Módulo 1/dataset_total_vacunas.csv")
# data
# FECHA_ADMINISTRACION	GRUPO_ETARIO	GENERO	VACUNA	TIPO_EFECTOR	DOSIS_1	DOSIS_2	ID_CARGA	DOSIS_3
# 0	08JAN2021:00:00:00	41 a 50	F	Sputnik	Público nacional	14.0	0.0	NaN	0.0
# 1	08JAN2021:00:00:00	41 a 50	M	Sputnik	Privado	18.0	0.0	NaN	0.0
# 2	08JAN2021:00:00:00	41 a 50	M	Sputnik	Público	168.0	0.0	NaN	0.0
# 3	08JAN2021:00:00:00	41 a 50	M	Sputnik	Público nacional	4.0	0.0	NaN	0.0
# 4	08JAN2021:00:00:00	51 a 60	F	Sputnik	Privado	14.0	0.0	NaN	0.0
# ...	...	...	...	...	...	...	...	...	...
# 27806	31JAN2022:00:00:00,51 a 60,M,"vacuna Coronavir...	NaN	NaN	NaN	NaN	NaN	NaN	NaN	NaN
# 27807	31JAN2022:00:00:00	61 a 70	F	AstraZeneca	Público	3.0	4.0	NaN	18.0
# 27808	31JAN2022:00:00:00	61 a 70	F	Moderna	Público	0.0	3.0	NaN	484.0
# 27809	31JAN2022:00:00:00	61 a 70	F	Sinopharm	Público	2.0	12.0	NaN	0.0
# 27810	31JAN2022:00:00:00	61 a 70	F	Sputnik	Público	1.0	13.0	NaN	0.0
# 27811 rows × 9 columns
#
# # Ejercicios pandas 1: exploración
# Ver las 3 útlimas filas del dataset.
#
# Ver el tamaño del dataset
#
# Ver los nombres de las columnas
#
# Seleccionar la columna "TIPO_EFECTOR". Ver que valores toma esa columna y cuántos registros hay de cada uno.
#
# ¿Cuál es el registro en el que se dieron mayor cantidad de vacunas de DOSIS_1? ¿Cuántas vacunas se dieron? ¿Y de DOSIS_2?
#
# Eliminar la columna "ID_CARGA
#
# Cambiar los nombres de todas las columnas a minuscula
#
# # Ejercicios pandas 2: filtrar y agrupar
# Crear un nuevo Dataframe solamente con las vacunas aplicadas en Efectores Públicos.
#
# Crear un nuevo Dataframe solamente con las vacunas aplicadas a personas de entre 41 a 50 años.
#
# Calcular cuántas vacunas DOSIS_1 "Sinopharm" se dieron en efectores Públicos. Hacer con dos filtros, debe usarse el signo "&" y colocar cada uno entre parentesis: [(filtro1) & (filtro2)]
#
# Calcular cuántas vacunas "Sputik" DOSIS_2 se dieron a mujeres.
#
# Generar un Dataframe con la cantidad de vacunas DOSIS_1 que se dieron para mujeres. Y generar otro Dataframe para hombres. Usar groupby.
#
# Generar un Dataframe que tenga la cantidad de vacunas DOSIS_1 aplicadas a mujeres y hombres de cada tipo de vacuna. Usar groupby.
#
# Calcular cuántas vacunas de DOSIS_1 y cuantas vacunas de DOSIS_2 se dieron en cada efector, y en total (sumadas las dos).

# %%
listadematerias=["literatura","matematica","arte"]
print(listadematerias)
# Out:
# ['literatura', 'matematica', 'arte']

# %%
print(listadematerias)
listadematerias.remove("literatura")
print(listadematerias)
# Out:
# ['literatura', 'matematica', 'arte']
# ['matematica', 'arte']

# %%
listadematerias.append("filosofa")
print(listadematerias)
# Out:
# ['matematica', 'arte', 'filosofa']

# %%
listadematerias[1]
# Out:
# 'arte'

# %%
Diccionario={"materia": ["literatura","matematica","arte"], "profesor":["Debora","Sofia","Luca"]}
print(Diccionario["materia"])
print(Diccionario["profesor"])
# Out:
# ['literatura', 'matematica', 'arte']
# ['Debora', 'Sofia', 'Luca']

# %%
Diccionario["proyecto"]="Maria"
print(Diccionario)
# Out:
# {'materia': ['literatura', 'matematica', 'arte'], 'profesor': ['Debora', 'Sofia', 'Luca'], 'proyecto': 'Maria'}

# %%
num1 =10
num2 =10
if num1 != num2:
  print ("son distintos")
else :
  print("son iguales")
# Out:
# son iguales

# %%
si_no_llueve = False
esta_lloviendo =True
if si_no_llueve:
  print("podemos ir a la plaza")
else:
    print("debemos quedarnos en casa")
# Out:
# debemos quedarnos en casa

# %%
lista =[6,8,2]
for Número in lista:
  print(Número+2)
# Out:
# 8
# 10
# 4

# %%
def list(cantidad):
    contador = 0
    for i in cantidad:
        contador+=1
    return contador

Materias=["arte","matematica","literatura","geografia","filosofa"]
print(" ",list(Materias))
# Out:
#   5

# %%
def calculadora(num1, num2, operation):
    if operation ==  "dividir":
        return num1 / num2
    
calculadora(4,2,"dividir")
# Out:
# 2.0

# %%
calculadora(4,2,"dividir")
def calculadora(num1, num2, operation):
    if operation == "dividir" and num2!=0:
        return num1 / num2
    else:
        print("no se puede realizar esta operación")

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Dataset Proyecto Modulo 1 - Plan de vacunacion COVID-19.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-9f2670bd6e3c> in <module>()
# ----> 1 data = pd.read_csv("/content/Dataset Proyecto Modulo 1 - Plan de vacunacion COVID-19.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data.head()
# Out:
#   FECHA_ADMINISTRACION GRUPO_ETARIO GENERO   VACUNA      TIPO_EFECTOR  \
# 0   08JAN2021:00:00:00      41 a 50      F  Sputnik  Público nacional
# 1   08JAN2021:00:00:00      41 a 50      M  Sputnik           Privado
# 2   08JAN2021:00:00:00      41 a 50      M  Sputnik           Público
# 3   08JAN2021:00:00:00      41 a 50      M  Sputnik  Público nacional
# 4   08JAN2021:00:00:00      51 a 60      F  Sputnik           Privado
#
#    DOSIS_1  DOSIS_2  ID_CARGA  DOSIS_3
# 0     14.0      0.0       NaN      0.0
# 1     18.0      0.0       NaN      0.0
# 2    168.0      0.0       NaN      0.0
# 3      4.0      0.0       NaN      0.0
# 4     14.0      0.0       NaN      0.0

# %%
 data.loc[:,["DOSIS_2", "ID_CARGA","DOSIS_3",]]
# Out:
#        DOSIS_2  ID_CARGA  DOSIS_3
# 0          0.0       NaN      0.0
# 1          0.0       NaN      0.0
# 2          0.0       NaN      0.0
# 3          0.0       NaN      0.0
# 4          0.0       NaN      0.0
# ...        ...       ...      ...
# 27806      NaN       NaN      NaN
# 27807      4.0       NaN     18.0
# 27808      3.0       NaN    484.0
# 27809     12.0       NaN      0.0
# 27810     13.0       NaN      0.0
#
# [27811 rows x 3 columns]

# %%
data.shape
# Out:
# (27811, 9)

# %%
data.columns
# Out:
# Index(['FECHA_ADMINISTRACION', 'GRUPO_ETARIO', 'GENERO', 'VACUNA',
#        'TIPO_EFECTOR', 'DOSIS_1', 'DOSIS_2', 'ID_CARGA', 'DOSIS_3'],
#       dtype='object')

# %%
data.loc[:,["TIPO_EFECTOR",]]
# Out:
#            TIPO_EFECTOR
# 0      Público nacional
# 1               Privado
# 2               Público
# 3      Público nacional
# 4               Privado
# ...                 ...
# 27806               NaN
# 27807           Público
# 27808           Público
# 27809           Público
# 27810           Público
#
# [27811 rows x 1 columns]
