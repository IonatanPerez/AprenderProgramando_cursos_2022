# %%
v1 = 10
v2 = 2
print(v1+v2)
print(v1-v2)
print(v1*v2)
print(v1/v2)
# Out:
# 12
# 8
# 20
# 5.0

# %%
grupo1 = ["Marcelo","Oscar","Walter"]
grupo2 = ["Mauro","Ezequiel","Lombardo"]
print(grupo1)
print(grupo2)
# Out:
# ['Marcelo', 'Oscar', 'Walter']
# ['Mauro', 'Ezequiel', 'Lombardo']

# %%
grupo3 = []
grupo3.append(grupo1[2])
grupo3.append(grupo2[2])
print(grupo3)
# Out:
# ['Walter', 'Lombardo']

# %%
print(grupo1)
grupo1.pop()
print(grupo1)

print(grupo2)
grupo2.pop()
print(grupo2)
# Out:
# ['Marcelo', 'Oscar', 'Walter']
# ['Marcelo', 'Oscar']
# ['Mauro', 'Ezequiel', 'Lombardo']
# ['Mauro', 'Ezequiel']

# %%
todos = grupo1 + grupo2 + grupo3
print(todos)
# Out:
# ['Marcelo', 'Oscar', 'Mauro', 'Ezequiel', 'Walter', 'Lombardo']

# %%
diccionario = {"Argentina":"Buenos Aires","Colombia":"Bogotá","Brasil":" Brasilia"}
print(diccionario.keys())
print(diccionario.values())
diccionario["Francia"] = "Paris"
diccionario.items()
# Out:
# dict_keys(['Argentina', 'Colombia', 'Brasil'])
# dict_values(['Buenos Aires', 'Bogotá', ' Brasilia'])
# dict_items([('Argentina', 'Buenos Aires'), ('Colombia', 'Bogotá'), ('Brasil', ' Brasilia'), ('Francia', 'Paris')])
