# %%
import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
data = pd.read_csv("/content/pokemon.csv.zip")

# %%
data.head(3)
# Out:
#       nombre  indice_guia  resistencia  ataque  defensa tipo_primario  \
# 0  Bulbasaur            1        128.0   118.0    111.0         Grass
# 1    Ivysaur            2        155.0   151.0    143.0         Grass
# 2   Venusaur            3        190.0   198.0    189.0         Grass
#
#   tipo_secundario  max_salud  tasa_captura  tasa_escape  Weight  Height  \
# 0          Poison      113.0          0.20         0.10     6.9     0.7
# 1          Poison      134.0          0.10         0.07    13.0     1.0
# 2          Poison      162.0          0.05         0.05   100.0     2.0
#
#   Legendario  generacion  fuerza_combate
# 0         No           1            1115
# 1         No           1            1699
# 2         No           1            2720

# %%
data.shape
# Out:
# (649, 15)

# %%
data.dtypes
# Out:
# nombre              object
# indice_guia          int64
# resistencia        float64
# ataque             float64
# defensa            float64
# tipo_primario       object
# tipo_secundario     object
# max_salud          float64
# tasa_captura       float64
# tasa_escape        float64
# Weight             float64
# Height             float64
# Legendario          object
# generacion           int64
# fuerza_combate       int64
# dtype: object

# %%
data.columns
# Out:
# Index(['nombre', 'indice_guia', 'resistencia', 'ataque', 'defensa',
#        'tipo_primario', 'tipo_secundario', 'max_salud', 'tasa_captura',
#        'tasa_escape', 'Weight', 'Height', 'Legendario', 'generacion',
#        'fuerza_combate'],
#       dtype='object')

# %%
dict_renombrar= {"Weight":"Peso", "Height":"Altura"}

data.rename(columns=dict_renombrar, inplace =True)

# %%
data.head(2)
# Out:
#       nombre  indice_guia  resistencia  ataque  defensa tipo_primario  \
# 0  Bulbasaur            1        128.0   118.0    111.0         Grass
# 1    Ivysaur            2        155.0   151.0    143.0         Grass
#
#   tipo_secundario  max_salud  tasa_captura  tasa_escape  Peso  Altura  \
# 0          Poison      113.0           0.2         0.10   6.9     0.7
# 1          Poison      134.0           0.1         0.07  13.0     1.0
#
#   Legendario  generacion  fuerza_combate
# 0         No           1            1115
# 1         No           1            1699

# %%
data.isnull()
# Out:
#      nombre  indice_guia  resistencia  ataque  defensa  tipo_primario  \
# 0     False        False        False   False    False          False
# 1     False        False        False   False    False          False
# 2     False        False        False   False    False          False
# 3     False        False        False   False    False          False
# 4     False        False        False   False    False          False
# ..      ...          ...          ...     ...      ...            ...
# 644   False        False        False   False    False          False
# 645   False        False        False   False    False          False
# 646   False        False        False   False    False          False
# 647   False        False        False   False    False          False
# 648   False        False        False   False    False          False
#
#      tipo_secundario  max_salud  tasa_captura  tasa_escape   Peso  Altura  \
# ...

# %%
data.isnull().sum()
# Out:
# nombre             0
# indice_guia        0
# resistencia        5
# ataque             5
# defensa            5
# tipo_primario      5
# tipo_secundario    5
# max_salud          5
# tasa_captura       5
# tasa_escape        5
# Peso               0
# Altura             4
# Legendario         1
# generacion         0
# fuerza_combate     0
# dtype: int64

# %%
nulo_resistencia = data["resistencia"].isnull()
nulo_resistencia
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 644    False
# 645    False
# 646    False
# 647    False
# 648    False
# Name: resistencia, Length: 649, dtype: bool

# %%
data.loc[nulo_resistencia]
# Out:
#        nombre  indice_guia  resistencia  ataque  defensa tipo_primario  \
# 175   Togetic          176          NaN     NaN      NaN           NaN
# 248     Lugia          249          NaN     NaN      NaN           NaN
# 345   Cradily          346          NaN     NaN      NaN           NaN
# 568  Garbodor          569          NaN     NaN      NaN           NaN
# 580    Swanna          581          NaN     NaN      NaN           NaN
#
#     tipo_secundario  max_salud  tasa_captura  tasa_escape   Peso  Altura  \
# 175             NaN        NaN           NaN          NaN    3.2    0.61
# 248             NaN        NaN           NaN          NaN  216.0    5.21
# 345             NaN        NaN           NaN          NaN   60.4    1.50
# 568             NaN        NaN           NaN          NaN  107.3    1.90
# 580             NaN        NaN           NaN          NaN   24.2    1.30
#
#     Legendario  generacion  fuerza_combate
# 175         No           2            1708
# ...

# %%
data.loc[nulo_resistencia, "resistencia"]
# Out:
# 175   NaN
# 248   NaN
# 345   NaN
# 568   NaN
# 580   NaN
# Name: resistencia, dtype: float64

# %%
data["resistencia"].unique()
# Out:
# array([128.0, 155.0, 190.0, 118.0, 151.0, 186.0, 127.0, 153.0, 188.0,
#        137.0, 120.0, 163.0, 160.0, 195.0, 102.0, 146.0, 111.0, 181.0,
#        172.0, 207.0, 130.0, 156.0, 191.0, 216.0, 116.0, 177.0, 251.0,
#        295.0, 67.0, 93.0, 141.0, 233.0, 198.0, 487.0, 85.0, 277.0, 134.0,
#        330.0, 121.0, 209.0, 214.0, 225.0, 268.0, 110, 382.0, 496.0, 99.0,
#        169.0, 284.0, 104.0, 1.0, 162.0, 197.0, 232.0, 176.0, 302.0, 347.0,
#        242.0, 125.0, 165.0, 223.0, 205.0, 213.0, 183.0, 142.0, 114.0,
#        184.0, 167.0, 219.0, 244.0, 312.0, 135.0, 174.0, 230.0, 149.0,
#        239.0, 286.0, 179.0, 170.0, 200.0, 189.0, 221.0, 260.0, 237.0,
#        253.0, 158.0, 144.0, 113.0, 139.0, 249.0, 338.0, 240.0, 211.0,
#        245.0], dtype=object)

# %%
import random

lista_imputar = random.choices(["110", "212", "172","120",], k=7)  #correr varias veces para ver como se modifica
lista_imputar
