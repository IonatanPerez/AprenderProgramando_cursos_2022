# %% [markdown]
# **EJERCICIOS TIPOS DE DATOS:**
# 1. Hacer una lista que contenga 3 materias de la escuela.
# 2. Eliminar el primer registro de la lista.
# 3. Agregar una materia más al final.
# 4. Seleccionar el segundo elemento de la lista.
# 5. Crear un diccionario con las materias y el nombre del/la profesor/a.
# 6. Agregar una materia y un/a profesor/a.
# 7. Eliminar una materia y un/a profesor/a

# %%
materias=["geografia","matematica","historia"]
print(materias)
# Out:
# ['geografia', 'matematica', 'historia']

# %%
print(materias)
materias.remove("geografia")
print(materias)
# Out:
# ['geografia', 'matematica', 'historia']
# ['matematica', 'historia']

# %%
materias.append("lengua")
print(materias)
# Out:
# ['matematica', 'historia', 'lengua']

# %%
materias[1]
# Out:
# 'historia'

# %%
registro={"matematica":"narvaja","historia":"imanol","lengua":"perez"}
print(registro)
# Out:
# {'matematica': 'narvaja', 'historia': 'imanol', 'lengua': 'perez'}

# %%
registro["artistica"]="lopez"
print(registro)
# Out:
# {'matematica': 'narvaja', 'lengua': 'perez', 'artistica': 'lopez'}

# %%
print(registro)
# Out:
# {'matematica': 'narvaja', 'artistica': 'lopez'}

# %% [markdown]
# **EJERCICIOS ESTRUCTURAS DE CONTROL**
# 1. Definir 2 variables con números (num1 y num2). Crear una estructura condcional donde si los dos números son iguales se imprima "los dos números son iguales"  (*if... else...*)
# 2. Crear una estructura condicional donde si "no llueve", "podemos ir a la plaza", y sino "debemos quedarnos en casa" (*if... else... *)
# 3. Definir una lista con 3 números (puede ser la misma que antes). Crear una estructura iterativa donde se imprima cada número +2 (*for... in...*)
# 4. Crear una lista con 5 materias de la escuela. Crear una esctructura iterativa que permita CONTAR la cantidad de elementos en la lista (*for... in...*)
# 5. Crea una función que divida dos números que reciba como parámetros
# 6. Crea una función que reciba 2 números e incluya una condicional donde si el segundo número es 0 imprima "no se puede realizar esta operación" y sino realice una división entre el primer y el segundo número
# 7. Crear una función que dada una losta de números y un número (parámetros), agregue el números a lista (*def*)

# %%
num1=56
num2=56
if num1==num2:
  print("los dos números son iguales")
else:
    print("los dos números son distintos")
# Out:
# los dos números son iguales

# %%
no_llueve = False
esta_lloviendo =True
if no_llueve:
  print("podemos ir a la plaza")
else:
    print("debemos quedarnos en casa")
# Out:
# debemos quedarnos en casa

# %%
lista=[3,2,6]
resultado=0
for num in lista:
  resultado=resultado+num
  print(resultado)
# Out:
# 3
# 5
# 11

# %%
materias=["lengua","matematica","historia","artistica","quimica"]
contador=0
for i in materias:
  contador+=1
  print(contador)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num1=3
num2=4
def division(num1,num2):
  division=num1/num2
  return division
  print(division)

# %%
num1=9
num2=4
def calculadora(num1,num2,operacion):
  if operacion == "division" and num2!=0:
    return num1 / num2
  else:
    print("no se puede realizar esta operacion")

# %%
def contador [2,3,4]:
  contar=(contador)
  for i in lista:
    contar+=1
    return contar
# Out:
#   File "<ipython-input-22-728540d5d7e9>", line 1
#     def contador [2,3,4]:
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# **EJERCICIOS PANDAS 1: EXPLORACIÓN**
# 1. ver las 3 últimas filas del dataset.
# 2. Ver el tamaño del dataset.
# 3. Ver los nombres de las columnas.
# 4. Seleccionar la columna "TIPO_EFECTOR". Ver que valores toma esa columna y cuántos registros hay de cada uno.
# 6. Eliminar la columna "ID_CARGA"
# 7. Cambiar los nombres de todas las columnas a minuscula.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
data= pd
