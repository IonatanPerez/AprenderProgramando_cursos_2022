# %%
numerospares= 
print(numerospares)
# Out:
# 10094

# %%
if 3!=2:
  print("son distintos")
# Out:
# son distintos

# %%
contador=0
amigos=["Lucía","Eduardo","María","José"]
for i in amigos:
  contador+=1
  print(contador)
# Out:
# 1
# 2
# 3
# 4

# %%
numeros=[4,5,6]
resultado1=4
resultado2=5
resultado3=6

for num in numeros:
 resultado1 = resultado1*-1
 resultado2 = resultado2*-1
 resultado3 = resultado3*-1
 print(resultado1, resultado2, resultado3)
# Out:
# -4 -5 -6
# 4 5 6
# -4 -5 -6

# %%
num1=8
num2=9

def suma(num1,num2):
 print(num1,num2)

# %%
num1=2
num2=3
num3=4

def calculadora (num1, num2, num3, operacion):
  if operacion == "multiplicacion":
   return num1*num2*num3
