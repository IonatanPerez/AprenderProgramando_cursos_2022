# %% [markdown]
# #Tarea clase 2

# %% [markdown]
# #Optativo

# %%
#Armar una lista con 6 ciudades
ciudades = ["Cordoba", "Buenos Aires", "Corrientes", "Salta", "Santa fe", "Rosario"]
#Tomar la segunda ciudad
segundaciudad = ciudades[1:2]
print(segundaciudad)
#Eliminar la ultima ciudad
ciudades.pop()
#Reemplazar la primera ciudad con otra
ciudades[0]= "Mar del plata"
print(ciudades)
#Agregar una ciudad al final
ciudades.append("Bariloche")
print(ciudades)
#Armar un diccionario con 3 duplas provincia-ciudad
diccionario = {"Provincia de chaco": "Resistencia", "Provincia de Salta": "Cachi", "Provincia de Cordoba": "Jesus María"}
#Eliminar el ultimo registro
diccionario.popitem()
#Ver keys
print(diccionario.keys())
# Out:
# ['Buenos Aires']
# ['Mar del plata', 'Buenos Aires', 'Corrientes', 'Salta', 'Santa fe']
# ['Mar del plata', 'Buenos Aires', 'Corrientes', 'Salta', 'Santa fe', 'Bariloche']
# dict_keys(['Provincia de chaco', 'Provincia de Salta'])

# %%
N1 = 235
N2 = 300
#Suma y Resta
print(N1 + N2)
print(N1 - N2)
#Multiplicacion y Division
print(N1 * N2)
print(N1/N2)
#----------------------
#Crear 2 listas con 3 nombres
grupo_1 = ["adolfo", "miguel", "geovani"]
grupo_2 = ["cecilia", "marta", "tiziano"]
#Grupo 3 con valores de grupo 2 y 1
grupo_3 = []
grupo_3.append(grupo_1[2:])
grupo_3.append(grupo_2[2:])
print(grupo_3)
#Crear una lista "TODOS" con todos los valores de las demas listas
todos = grupo_1 + grupo_2 + grupo_3
print(todos)
#Eliminar los dos nombres de los grupos 1 y 2
grupo_1.pop()
grupo_2.pop()
print(grupo_1, grupo_2)

#Crear un Diccionario, mostrar el nombre del pais y de su capital
diccionario = {"Argentina": "Buenos Aires", "Paraguay": "Asuncion", "Bolivia": "La Paz"}
print(diccionario.keys())
for i in diccionario: 
  print(diccionario.values())
#Agregar un par pais-capital
diccionario["Brasil"]= "Brasilia"
print(diccionario)
# Out:
# 535
# -65
# 70500
# 0.7833333333333333
# [['geovani'], ['tiziano']]
# ['adolfo', 'miguel', 'geovani', 'cecilia', 'marta', 'tiziano', ['geovani'], ['tiziano']]
# ['adolfo', 'miguel'] ['cecilia', 'marta']
# dict_keys(['Argentina', 'Paraguay', 'Bolivia'])
# dict_values(['Buenos Aires', 'Asuncion', 'La Paz'])
# dict_values(['Buenos Aires', 'Asuncion', 'La Paz'])
# dict_values(['Buenos Aires', 'Asuncion', 'La Paz'])
# {'Argentina': 'Buenos Aires', 'Paraguay': 'Asuncion', 'Bolivia': 'La Paz', 'Brasil': 'Brasilia'}
