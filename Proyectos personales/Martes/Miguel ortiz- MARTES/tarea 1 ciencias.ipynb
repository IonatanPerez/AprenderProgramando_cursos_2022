# %% [markdown]
# #Miguel ortiz
#  tengo 16 años y estudio electronica
#
# ![Captura de pantalla 2022-04-20 004422.png](data:image/png;base64,...)
#
# #mis pasatiempos
#
#
#
#
#
#
# *   Jugar al pc toda clase de juegos
# *   hacer boludeces
# *   mirar partidos de futbol
# *   jugar a lol

# %%
nombre = "miguel"
for j in range(1,100):
 print(nombre)
# Out:
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
# miguel
