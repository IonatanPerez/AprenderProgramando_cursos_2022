# %% [markdown]
# Ejercicios
# Crea una nueva celda de código, e intenta resolver estos ejercicios utilizando python.
#
# 1. Hacer un texto que tenga sus nombres 100 veces.
#
# 2. 15 amigos/as juntan 250 pesos cada uno. ¿cuanto reunieron?, ¿que tipo de dato es el resultado?.

# %%
# Hacer un texto que tenga sus nombres 100 veces.
texto = input("Ingrese su nombre: ")
repeticion = texto *100
print(repeticion )
            # o 
text = input ("Ingrese su nombre: ")
rep = 100
for i in range (rep):
  print(text+"\n")

# %%
#15 amigos/as juntan 250 pesos cada uno. ¿cuanto reunieron?, ¿que tipo de dato es el resultado?.
personas = 15 
pesos = 250
resultado = personas *pesos
print("$",resultado)
type (resultado)
#         o
pers = int(input("ingrese la cantidad de personas: "))
plata = int(input("Ingrese la cantidad de plata: "))
res = pers*plata
print("$",res) 
type (res)

# %% [markdown]
# #  ***Clase 2***
#
# #Tarea
# Hacer en una notebook nueva los siguientes ejercicios:
#
# Crea dos variables con valores enteros y luego imprime los resultados de su suma, resta, multiplicación y división.
#
# Crea dos listas con 3 nombres cada una llamadas grupo1 y grupo2.
#
# Crea una tercera lista llamada grupo3 con los últimos nombres de cada una de las listas grupo1 y grupo2 y elimina esos nombres de las listas originales.
#
# Crea una lista llamada todos con todos los nombres de las listas.
#
# Crea un diccionario que tenga 3 pares de clave valor con países y capitales.
#
# Hace un print de los nombres de lo países.
#
# Mostrá los nombres de las capitales
#
# Agrega una par de país-capital
#
# #Optativos
# Armar una lista con 6 ciudades
#
# Seleccionar la segunda ciudad
#
# Eliminar la última ciudad
#
# Reemplazar la primer ciudad con otra
#
# Agregar una ciudad al final
#
# Armar un diccionario que tenga 3 duplas de Provincia y Ciudad (ej: "Provincia de Buenos Aires: La Plata"
#
# Eliminar el último registro (dupla Ciudad-Provincia)
#
# Ver todas las claves (keys)

# %%
# Crea dos variables con valores enteros y luego imprime los resultados de su suma, resta, multiplicación y división.
def menu():
    print("Operaciones. \n 1. Suma \n 2. Resta \n 3. Multiplicacion \n 4. Division \n 5. Salir ")
    op = int(input ("Escriba el numero de la opcion:"))
    if op==1: suma()
    elif op==2: resta()
    elif op==3: multiplicacion()
    elif op==4: division()
    else: exit()
def suma():
    print(" \n Hacer sumas.")
    num1 = float(input("Numero 1: "))
    num2 = float(input("Numero 2: "))
    print (" \n Resultado: ", num1+num2,"\n")
    menu()
def resta():
    print(" \n Hacer restas.")
    num1 = float(input("Numero 1: "))
    num2 = float(input("Numero 2: "))
    print (" \n Resultado: ", num1-num2,"\n")
    menu()
def multiplicacion():
    print(" \n Hacer multiplicación.")
    num1 = float(input("Numero 1: "))
    num2 = float(input("Numero 2: "))
    print (" \n Resultado: ", num1*num2, "\n")
    menu()
def division():
    print(" \n Hacer división.")
    num1 = float(input("Numero 1: "))
    num2 = float(input("Numero 2: "))
    print ("\n Resultado: ", num1/num2,"\n")
    menu()
menu()

# %%
#Crea dos listas con 3 nombres cada una llamadas grupo1 y grupo2.
#Crea una tercera lista llamada grupo3 con los últimos nombres de cada una de las listas grupo1 y grupo2 y elimina esos nombres de las listas originales.
#Crea una lista llamada todos con todos los nombres de las listas.

grupo1 = ["Emiliano","Laura","Lautaro"]
grupo2 = ["Belen","Roberto","Cecilia"]
grupo3 = []

print("Primera parte\nGrupo 1 \n ", grupo1, " \nGrupo 2 \n ", grupo2, " \nGrupo 3 \n ", grupo3)

quitar = grupo1.pop()
quitar2 = grupo2.pop()

add = grupo3.append(quitar)
add2 = grupo3.append(quitar2)

print("\nSegunda parte\n El Grupo 3\n", grupo3, "\nGrupo 1\n", grupo1, "\nGrupo2\n" ,grupo2)

todos=[]
todos.extend(grupo1+grupo2+grupo3)
print("\nTerceraparte\nTodos \n",todos)

# %%
#Crea un diccionario que tenga 3 pares de clave valor con países y capitales.

#Hace un print de los nombres de lo países.

#Mostrá los nombres de las capitales

#Agrega una par de país-capital

diccionario = {"Afganistán": ["Kabul"], "Albania": ["Tirana"],"Alemania": ["Berlin"]}
print("Nombre de los paises",diccionario.keys(),"\nNombre de las capitales",diccionario["Afganistán"], diccionario["Albania"],diccionario["Alemania"])
diccionario["Alemania"].append("Hola")
diccionario["Andorra"] = "Andorra la Vieja"
print(diccionario)
# Out:
# Nombre de los paises dict_keys(['Afganistán', 'Albania', 'Alemania'])
# Nombre de las capitales ['Kabul'] ['Tirana'] ['Berlin']
# {'Afganistán': ['Kabul'], 'Albania': ['Tirana'], 'Alemania': ['Berlin', 'Hola'], 'Andorra': 'Andorra la Vieja'}

# %%
#Armar una lista con 6 ciudades
#Seleccionar la segunda ciudad
#Eliminar la última ciudad
#Reemplazar la primer ciudad con otra
#Agregar una ciudad al final

list = ["e0","2","r","re","r6","ret"]
print("Segunda ciudad ",list[1])
list.pop(len(list)-1)
print("Eliminar ultima ",list)
list[0]="a"
print("Remplazar ",list)
list.append("g")
print("Agregar al final ",list)
# Out:
# Segunda ciudad  2
# Eliminar ultima  ['e0', '2', 'r', 're', 'r6']
# Remplazar  ['a', '2', 'r', 're', 'r6']
# Agregar al final  ['a', '2', 'r', 're', 'r6', 'g']

# %%
#Armar un diccionario que tenga 3 duplas de Provincia y Ciudad (ej: "Provincia de Buenos Aires: La Plata"

#Eliminar el último registro (dupla Ciudad-Provincia)

#Ver todas las claves (keys)
dicc = {"Provincia de Buenos Aires": "La Plata","a":"aa", "AA":"dd"} 
dicc.pop("AA",None)
print(dicc.keys())

# %%
import pandas as pd
data = pd.read_csv("control.csv", encoding = 'ISO-8859-1', sep=";")

# %%
data.head()
data.sharpe
data.fecha
data.fecha.tail()
data.Suma_de_CANTIDAD.sum()
data.Suma_de_CANTIDAD.max()
