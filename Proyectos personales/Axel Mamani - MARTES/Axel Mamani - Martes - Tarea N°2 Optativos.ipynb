# %%
# Ejercicio Nro. 1 - Armar una lista con 6 ciudades

lista_ciudades = ['Sidney', 'Denver', 'Orlando', 'Roma', 'Londres', 'Helsinki']
print(lista_ciudades)

# Ejercicio Nro. 2 - Seleccionar la segunda ciudad

print(lista_ciudades[1])

# Ejercicio Nro. 3 - Eliminar la última ciudad

eliminar = lista_ciudades.pop()
print(lista_ciudades)

# Ejercicio Nro. 4 - Reemplazar la primer ciudad con otra

lista_ciudades[0] = "Montevideo"
print(lista_ciudades)

# Ejercicio Nro. 5 - Agregar una ciudad al final

ciudad = "Santiago de Chile"
agregar = lista_ciudades.append(ciudad)
print(lista_ciudades)
# Out:
# ['Sidney', 'Denver', 'Orlando', 'Roma', 'Londres', 'Helsinki']
# Denver
# ['Sidney', 'Denver', 'Orlando', 'Roma', 'Londres']
# ['Montevideo', 'Denver', 'Orlando', 'Roma', 'Londres']
# ['Montevideo', 'Denver', 'Orlando', 'Roma', 'Londres', 'Santiago de Chile']

# %%
# Ejercicio Nro. 6 - Armar un diccionario que tenga 3 duplas de Provincia y Ciudad (ej: "Provincia de Buenos Aires: La Plata"

diccionario_c = {'Catamarca': 'San Fernando', 'jujuy': 'San Salvador', 'Tierra del Fuego': 'Ushuaia'}
print(diccionario_c)

# Ejercicio Nro. 7 - Eliminar el último registro (dupla Ciudad-Provincia)

eliminar_dupla = diccionario_c.pop('Tierra del Fuego')
print(diccionario_c)

# Ejercicio Nro. 8 - Ver todas las claves (keys)

keys = diccionario_c.keys()
print(keys)
# Out:
# {'Catamarca': 'San Fernando', 'jujuy': 'San Salvador', 'Tierra del Fuego': 'Ushuaia'}
# {'Catamarca': 'San Fernando', 'jujuy': 'San Salvador'}
# dict_keys(['Catamarca', 'jujuy'])
