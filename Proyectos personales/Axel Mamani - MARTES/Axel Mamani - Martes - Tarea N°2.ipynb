# %%
# Ejercicio Nro: 2

grupo1 = ["Facundo", "Sammy", "Alex"]
grupo2 = ["Rodrigo", "Alvarez", "Lucio"]

print("Lista nro. 1 y nro. 2: ")
print(grupo1, grupo2)

# Ejercicio Nro: 3

nombre1 = grupo1.pop()
nombre2 = grupo2.pop()
grupo3 = [nombre1, nombre2]

print("Lista nro. 3: ")
print(grupo3)

# Ejercicio Nro. 4

todos = [grupo1 + grupo2 + grupo3]
print("Lista nro. 4: ")
print(todos)
# Out:
# Lista nro. 1 y nro. 2:
# ['Facundo', 'Sammy', 'Alex'] ['Rodrigo', 'Alvarez', 'Lucio']
# Lista nro. 3:
# ['Alex', 'Lucio']
# Lista nro. 4:
# [['Facundo', 'Sammy', 'Rodrigo', 'Alvarez', 'Alex', 'Lucio']]

# %%
# Ejercicio Nro: 1

v1 = int(8)
v2 = int(5)

suma = v1 + v2
resta = v1 - v2
division = v1 / v2
multiplicacion = v1 * v2
print(v1, v2)

print("Su suma es: ")
print(suma)

print("Su resta es: ")
print(resta)

print("Su division es: ")
print(division)

print("Su multiplicacion es: ")
print(multiplicacion)
# Out:
# 8 5
# Su suma es:
# 13
# Su resta es:
# 3
# Su division es:
# 1.6
# Su multiplicacion es:
# 40

# %%
# Ejercicio Nro. 5

diccionario = {'Argentina': 'Buenos Aires', 'Uruguay': 'Montevideo', 'Italia': 'Roma' }

# Ejercicio Nro 6

paises = diccionario.keys()
print(paises)

# Ejercicio Nro. 7

capitales = diccionario.values()
print(capitales)

# Ejercicio Nro. 8

diccionario['Brasil'] = 'Brasilia'
print(diccionario)
# Out:
# dict_keys(['Argentina', 'Uruguay', 'Italia'])
# dict_values(['Buenos Aires', 'Montevideo', 'Roma'])
# {'Argentina': 'Buenos Aires', 'Uruguay': 'Montevideo', 'Italia': 'Roma', 'Brasil': 'Brasilia'}
