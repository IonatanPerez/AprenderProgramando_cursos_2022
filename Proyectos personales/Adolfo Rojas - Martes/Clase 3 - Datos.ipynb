# %% [markdown]
# #Tarea 3 Ciencias

# %%
import math 
#Calcular la suma de los primeros 200 numeros pares
suma = 0
for i in range(0,201):
  if i % 2== 0:
    suma = suma+i
    i+1
print("la suma de todos da {}".format(suma))

#Crea un condicional que si dos números son distintos, imprima "son distintos"
n1 = int(input()) 

n2 = int(input())

if n1 != n2:
  print("son distintos")
else: 
  print("Son iguales")

#Crea una lista de amigos/as/es y crea una iteración que permita contar la cantidad de personas en la lista
n = ["Ariel", "Raul", "Roberto"]
contador = 0
for i in n:
  contador +=1

print("La cantidad de personas en la lista es de", contador)

#Crea una lista de números y una iteración que imprima en cada caso el número multiplicado por -1
numeros = [23,44,223,4423]

for i in numeros:
  print(i*-1)

#Crear una función que dados 2 números (parámetros), los sume (def)
def suma(num1, num2):
  sumatoria = num1 + num2 
  print(sumatoria)

#Crea una función que reciba una lista de números y de como resultado la multiplicación de todos ellos
def multiplicacion(lista):
  total = 1
  for i in lista:
    total *= i
  return total

lista = [12,234,12,43]
multiplicacion(lista)
