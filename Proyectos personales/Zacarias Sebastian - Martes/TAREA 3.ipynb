# %% [markdown]
# #Ejercicios
#
# ###1_ Calculen la suma de los primeros 200 números pares.
#
#
# ###2_ Crea un condicional que si dos números son distintos, imprima "son distintos". (distinto es !=)
#
#
# ###3_ Crea una lista de amigos/as/es y crea una iteración que permita contar la cantidad de personas en la lista.
#
#
# ###4_ Crea una lista de números y una iteración que imprima en cada caso el número multiplicado por -1
#
#
# ###5_ Crear una función que dados 2 números (parámetros), los sume (def)
#
#
# ###6_ Crea una función que reciba una lista de números y de como resultado la multiplicación de todos ellos

# %%
#1 
numerospares= 
print(numerospares)

# %%
#2
num1 = 44
num2 = 42
if num1 != num2:
  print ("son distintos")
else :
  print("son iguales")

# %%
#3
def list(cantidad):
    contador = 0
    for i in cantidad:
        contador+=1
    return contador

amigos=["Jesus","Melina","Mica","Sebastian"]
print("mis amigos son:",list(amigos))
# Out:
# mis amigos son: 4

# %%
#4
lista =[4,10,9,13]

for num in lista:
  print(num*-1)

# %%
#5
num1=2
num2=1
def calculadora(num1, num2, operation):
    if operation == "suma":
        return num1 + num2
    else:
        print("no anda")
  
calculadora(1,2,"suma")

# %%
#6
