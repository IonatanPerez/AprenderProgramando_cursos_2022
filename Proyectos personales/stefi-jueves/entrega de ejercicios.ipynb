# %% [markdown]
# en esta netbook

# %%
lista_de_materias = ["matematica","lengua","fisica"]

# %%
lista_de_materias.pop()
# Out:
#   File "<ipython-input-22-090445adc532>", line 1
#     lista_de_materias.pop()0
#                            ^
# SyntaxError: invalid syntax

# %%
lista_de_materias.append("biologia")

# %%
lista_de_materias
# Out:
# ['lengua', 'fisica', 'biologia']

# %%
lista_de_materias.pop()
# Out:
# 'biologia'

# %%
lista_de_materias[2]
# Out:
# 'biologia'
