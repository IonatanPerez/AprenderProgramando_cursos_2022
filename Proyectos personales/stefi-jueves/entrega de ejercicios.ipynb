# %% [markdown]
# en esta netbook

# %%
lista_de_materias = ["matematica","lengua","fisica"]

# %%
lista_de_materias.pop[]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-49d91b194f48> in <module>()
# ----> 1 lista_de_materias.pop[0]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
lista_de_materias.append("biologia")

# %%
lista_de_materias
# Out:
# ['lengua', 'fisica', 'biologia']

# %%
lista_de_materias.pop()
# Out:
# 'biologia'

# %%
lista_de_materias[2]
# Out:
# 'biologia'
