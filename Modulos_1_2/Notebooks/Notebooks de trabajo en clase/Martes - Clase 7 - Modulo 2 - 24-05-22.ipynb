# %%
# importamos librerias

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Dataset Clima.csv")
data.head()
# Out:
#    id  Humidity  Wind_Speed_kmh  rumbo_viento_grados  visibilidad_km  \
# 0   0      0.92           11.27                130.0            8.05
# 1   1      0.73           20.93                330.0           16.10
# 2   2      0.97            5.97                193.0           14.91
# 3   3      0.82            3.22                300.0           16.10
# 4   4      0.60           10.88                116.0            9.98
#
#    presion_mbar lluvia descripcion  temperatura
# 0       1021.60     no        Cold        -0.56
# 1       1017.00     si        Warm        21.11
# 2       1013.99     si      Normal        16.60
# 3       1031.59     si        Cold         1.60
# 4       1020.88     si        Cold         2.19

# %%
#Queremos ver el tamaño del dataset

data.shape
# Out:
# (10000, 9)

# %%
# queremos ver que tipo de datos hay en cada columna
data.dtypes
# Out:
# id                       int64
# Humidity               float64
# Wind_Speed_kmh         float64
# rumbo_viento_grados    float64
# visibilidad_km         float64
# presion_mbar           float64
# lluvia                  object
# descripcion             object
# temperatura            float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# id                     0
# Humidity               5
# Wind_Speed_kmh         5
# rumbo_viento_grados    5
# visibilidad_km         5
# presion_mbar           9
# lluvia                 1
# descripcion            8
# temperatura            0
# dtype: int64
