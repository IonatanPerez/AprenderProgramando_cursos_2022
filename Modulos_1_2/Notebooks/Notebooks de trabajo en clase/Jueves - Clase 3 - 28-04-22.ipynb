# %% [markdown]
# Arrancamos con un repaso de la clase pasada y vamos a tratar de ver mas tipos de datos, funciones y estructruas de control. Vamos a ver a que llegamos

# %%
lista_de_presentes = ["Camila 1","Breider","Alan","Joaquin","Sergio"]

lista_de_inscriptes = ["Camila 1","Camila 2","Breider","Ayax","Alan","Joaquin","Marco"]

# %% [markdown]
# Con las la lista de presentes y de insctriptes queremos hacer un codigo que nos diga quienes estan, quienes no y si hay algun infiltrade.

# %% [markdown]
# Vamos a tratar de pensar cuales son los pasos necesarios para hacer eso:

# %%
# Vamos a tratar de resolver el problema de los presentes

if "Camila 2" in lista_de_presentes:
  print ("Camila 2 esta presente.")
else:
  print ("Camila 2 esta ausente.")

if "Camila 1" in lista_de_presentes:
  print ("Camila 1 esta presente.")
else:
  print ("Camila 1 esta ausente.")

nombre = "Ayax"
if nombre in lista_de_presentes:
  print (nombre, "esta presente.")
else:
  print (nombre, "esta ausente.")

nombre = "Alan"
if nombre in lista_de_presentes:
  print (nombre, "esta presente.")
else:
  print (nombre, "esta ausente.")
# Out:
# Camila 2 esta ausente.
# Camila 1 esta presente.
# Ayax esta ausente.
# Alan esta presente.

# %%
# Vamos a definir una funcion que le paso el nombre y la lista de presentes y me dice si esta presente o no
def chequear_presente(nombre_de_persona,lista_de_curso):
  if nombre_de_persona in lista_de_curso:
    print (nombre_de_persona, "esta presente.")
  else:
    print (nombre_de_persona, "esta ausente.")

# %%
chequear_presente("Alan",lista_de_presentes)
chequear_presente("Camila 1",lista_de_presentes)
chequear_presente("Camila 2",lista_de_presentes)
# Out:
# Alan esta presente.
# Camila 1 esta presente.
# Camila 2 esta ausente.

# %%
lista_de_inscriptes[3]
# Out:
# 'Ayax'

# %%
numero_inscriptes = len(lista_de_inscriptes)

i = 0
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
i = i + 1
if i< numero_inscriptes:
  chequear_presente(lista_de_inscriptes[i],lista_de_presentes)
# Out:
# Camila 1 esta presente.
# Camila 2 esta ausente.
# Breider esta presente.
# Ayax esta ausente.
# Alan esta presente.
# Joaquin esta presente.
# Marco esta ausente.

# %%
# Vamos a ver que la posta es el for

for nombre in lista_de_inscriptes:
  print (nombre)


for nombre in lista_de_inscriptes:
  chequear_presente(nombre,lista_de_presentes)
# Out:
# Camila 1
# Camila 2
# Breider
# Ayax
# Alan
# Joaquin
# Marco
# Camila 1 esta presente.
# Camila 2 esta ausente.
# Breider esta presente.
# Ayax esta ausente.
# Alan esta presente.
# Joaquin esta presente.
# Marco esta ausente.

# %%
# Veamos como se comparan cosas:

primera_cosa = 4
segunda_cosa = 5

cosa_que_escribo = int(input())
print (cosa_que_escribo)
print (type(cosa_que_escribo))

# Nos fijamos si son iguales con un ==

if primera_cosa == cosa_que_escribo:
  print ("Son iguales!")
else:
  print ("Las dos cosas no son iguales.")
  print ("Lalalala!")
# Out:
# 4
# 4
# <class 'int'>
# Son iguales!

# %%
# Aca esta el programa andando

# Vamos a definir una funcion que le paso el nombre y la lista de presentes y me dice si esta presente o no
def chequear_presente(nombre_de_persona,lista_de_curso):
  if nombre_de_persona in lista_de_curso:
    print (nombre_de_persona, "esta presente.")
  else:
    print (nombre_de_persona, "esta ausente.")

# Cargar datos

lista_de_presentes = ["Camila 1","Breider","Alan","Joaquin","Sergio"]

lista_de_inscriptes = ["Camila 1","Camila 2","Breider","Ayax","Alan","Joaquin","Marco"]

# Ejecutamos la parte principal

for nombre in lista_de_inscriptes:
  chequear_presente(nombre,lista_de_presentes)

# Queda de tarea que hagan una version que chequee les infiltrades
# Out:
# Camila 1 esta presente.
# Camila 2 esta ausente.
# Breider esta presente.
# Ayax esta ausente.
# Alan esta presente.
# Joaquin esta presente.
# Marco esta ausente.

# %% [markdown]
# Super rapido diccionarios!

# %%
mi_diccionario = {}

mi_diccionario["Nombre del curso"] = "Ciencia de datos"
mi_diccionario["Comision"] = "Jueves turno mañana"
mi_diccionario["Inscriptes"] = ["Camila 1", "Camila 2", "Alan", "etc"]
mi_diccionario["Nro inscriptes"] = len(mi_diccionario["Inscriptes"])

print (mi_diccionario)
print (mi_diccionario["Comision"])
# Out:
# {'Nombre del curso': 'Ciencia de datos', 'Comision': 'Jueves turno mañana', 'Inscriptes': ['Camila 1', 'Camila 2', 'Alan', 'etc'], 'Nro inscriptes': 4}
# Jueves turno mañana
