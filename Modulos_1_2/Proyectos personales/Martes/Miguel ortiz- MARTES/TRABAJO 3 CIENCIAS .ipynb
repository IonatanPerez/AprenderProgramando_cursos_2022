# %%
#realizar la suma de los primeros 200 numeros pares
import math

suma = 0
for i in range(0,201):
  if i % 2 == 0:
    suma = suma+i
    i+1
print("la suma de todos da {}".format(suma))
# Out:
# la suma de todos da 10100

# %%
#Crea un condicional que si dos números son distintos, imprima "son distintos". (distinto es !=)

num1 = 72
num2 = 16

if num1 != num2:
    print(num1, "es distinto a", num2)
# Out:
# 72 es distinto a 16

# %%
#Crea una lista de amigos/as/es y crea una iteración que permita contar la cantidad de personas en la lista.
def contador(lista):
    contar = 0
    for i in lista:
        contar+=1
    return contar

lista_de_amigos= ["adolfo","mati", "franco", "tizi", "lauti", "escritorio"]

contador(lista_de_amigos)
# Out:
# 6

# %%
#Crea una lista de números y una iteración que imprima en cada caso el número multiplicado por -1

def multiplicar_lista(numeros):
  multiplicador = -1
  for numero in numeros:
    multiplicador *= numero
    
    return multiplicador
numeros=[2,3,4,5,6,7,8,9]

print(multiplicar_lista(numeros))
# Out:
# -2

# %%
#Crear una función que dados 2 números (parámetros), los sume (def)

def suma(numero1,numero2):
  sumatoria = numero1+numero2
  return sumatoria

  suma=(15,12)
  print(suma(numero1,numero2))

# %%
#Crea una función que reciba una lista de números y de como resultado la multiplicación de todos ellos

def multiplicar(lista_numeros):
  producto = 1
  for n in numeros:
    producto *= n
  return producto

  lista_numeros = (2,5,15,13)
  print(multiplicar(lista_numeros))
