# %%
paises = ("Argentina","Holanda","Francia")
print (paises)
# Out:
# ('Argentina', 'Holanda', 'Francia')

# %% [markdown]
# # NOMBRE Y APELLIDO
# *   SELENE ABULAFIA
# #EDAD
#
# *  18
#
# # PASATIEMPOS
#
# *   LEER
# *   DORMIR
# *   VER ANIME

# %%
"Selene "*100
# Out:
# 'Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene Selene '

# %%
75*45
# Out:
# 3375

# %%
type(3375)
# Out:
# int
