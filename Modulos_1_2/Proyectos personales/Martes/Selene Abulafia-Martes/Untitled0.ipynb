# %%
import pandas as pd

# %%
from google.colab import files
import io

# %%
filesUploaded = files.upload()
# Out:
#      <input type="file" id="files-c2b2be24-f144-4b8e-a043-60103842f863" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c2b2be24-f144-4b8e-a043-60103842f863">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving educacion ambiental.csv to educacion ambiental.csv

# %%
data = pd.read_csv(io.BytesIO(filesUploaded["educacion ambiental.csv"]), sep=";")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-33-855c67cf98ca> in <module>()
# ----> 1 data = pd.read_csv(io.BytesIO(filesUploaded["educacion ambiental.csv"]), sep=";")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# ¿Cuáles son los posibles destinatarios?

# %% [markdown]
# Mostrar la información de los encuentros del año 2019. Crear una máscara y luego acceder con .loc

# %% [markdown]
# Crea un Dafreame con los destinatarios de los encuentros del año 2019.

# %% [markdown]
# ¿Cuántos encuentros hubo en el año 2018?

# %% [markdown]
# ¿Cuántos encuentros hubo para "Almunos de nivel secundario"? Realizaro con sum() y luego crea un Dataframe con la información de este/esos encuentro/s

# %% [markdown]
# ¿Cuántos participantes promedio hubo por año? usar groupby

# %% [markdown]
# ¿Cuántos participantes de cada destinatario hubo? usar groupby

# %% [markdown]
# ¿Cuántos participantes hubo por año por destinatario por año? para hacer agrupaciones sobre 2 columnas se deben colocar entre corchetes dentro del parentesis (["columa1", "columna2"])
