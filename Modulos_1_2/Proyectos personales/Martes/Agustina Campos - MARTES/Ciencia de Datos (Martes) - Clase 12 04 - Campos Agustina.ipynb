# %%
print("Hola" * 100)
# Out:
# ...

# %%
resultado = (int)(250*15)
print("Total: " + (str)(resultado))
print("Tipo de Dato del Resultado: " + (str)(type(resultado)))
# Out:
# Total: 3750
# Tipo de Dato del Resultado: <class 'int'>
