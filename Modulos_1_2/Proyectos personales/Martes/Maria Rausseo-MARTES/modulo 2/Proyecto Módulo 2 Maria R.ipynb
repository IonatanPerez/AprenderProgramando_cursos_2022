# %% [markdown]
# #Proyecto Módulo 2
# **Ciencia de Datos**
#
# Maria Rausseo
#
#
# ---

# %% [markdown]
# **Preguntas orientadoras para responder:**
#
# **Características del dataset con el que trabajaron**
# *   ¿Qué columnas tiene?
# *   ¿Cuántos datos y registros tiene el dataset?
# *   ¿Qué nombre tiene cada columna?
# *   ¿Qué representan esos nombres?

# %%
import pandas as pd
import matplotlib.pyplot as plt  
import seaborn as sns

# %%
data = pd.read_csv("/content/data_clima_numerico_limpia.csv")

# %%
len(data.columns)
# Out:
# 9

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'humedad', 'velocidad_viento_kmh', 'rumbo_viento_grados',
#        'visibilidad_km', 'presion_mbar', 'lluvia', 'descripcion',
#        'temperatura'],
#       dtype='object')

# %%
data.head(2)
# Out:
#    Unnamed: 0  humedad  velocidad_viento_kmh  rumbo_viento_grados  \
# 0           0     0.92                 11.27                130.0
# 1           1     0.73                 20.93                330.0
#
#    visibilidad_km  presion_mbar lluvia descripcion  temperatura
# 0            8.05        1021.6     no        Cold        -0.56
# 1           16.10        1017.0     si        Warm        21.11

# %% [markdown]
# # LIMPIEZA DE DATOS
#
#
# *  ¿Qué columnas poseen valores faltantes o inválidos?
# *   ¿Cómo lo solucionaron?
# *   ¿Qué columnas tienen valores tipo texto y qué hicieron con las mismas?

# %%
from google.colab import files
import io

filesUploaded = files.upload()
data = pd.read_csv("/content/data_clima_numerico_limpia.csv")

# %%
nulo_visibilidad = data["visibilidad_km"].isnull()
nulo_visibilidad
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9990    False
# 9991    False
# 9992    False
# 9993    False
# 9994    False
# Name: visibilidad_km, Length: 9995, dtype: bool

# %%
data.loc[nulo_visibilidad]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, humedad, velocidad_viento_kmh, rumbo_viento_grados, visibilidad_km, presion_mbar, lluvia, descripcion, temperatura]
# Index: []

# %% [markdown]
# # REGRESIÓN LINEAL SIMPLE
#
# *   Elegir una columna y mostrar la relación entre esa columna y la variable fuerza de combate.
# *   Poner algún gráfico que muestre los resultados.

# %% [markdown]
# # REGRESIÓN LINEAL
#
# **Encontrar los coeficientes que corresponden a cada columna y el R2 del modelo.**

# %% [markdown]
# # CONCLUSIONES GENERALES
# **¿Qué aprendieron con este trabajo?**
