# %% [markdown]
# # INTRO
#
# # **Nombre** :
# Maria
# # **Apellido**:
# Rausseo
# # **Edad**:
# 17 años
#
# # Mis pasatiempos
#
# - hago tiktok
# - paseo con mi familia
# - escucho musica

# %% [markdown]
# # Codigo

# %%
"Maria"*100
# Out:
# '...'

# %%
def saludopersonalizado(nombre):
  print ("Hola " + nombre + " como andas?")

# %%
saludopersonalizado("Maria Rausseo")
# Out:
# Hola Maria Rausseo como andas?

# %%
(250*15)
# Out:
# 3750

# %%
type(250*15)
# Out:
# int
