# %% [markdown]
# #Ezequiel Alanis
# Tengo 16 años, voy a la escuela técnica 29
#
# ![yo](https://lh3.googleusercontent.com/a-/AOh14GjxNerU1ppVVjwzSPpxN0orVEtfURstBmVYBwsa=s270-p-rw-no)
#
#
# # Mis pasatiempos
#
# - Jugar a los juegitos
# - Dormir
# - Juntarme con mis amigos

# %%
print(3+7)
print(3-7)
print("holu")
# Out:
# 10
# -4
# holu

# %%
"ezequiel "*100
# Out:
# 'ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel ezequiel '

# %%
(250*15)

# %%
type (250*15)
# Out:
# int
