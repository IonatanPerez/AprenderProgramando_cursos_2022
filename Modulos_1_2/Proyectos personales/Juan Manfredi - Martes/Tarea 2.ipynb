# %% [markdown]
# #1
# Crea dos variables con valores enteros y luego imprime los resultados de su suma, resta, multiplicación y división.

# %%
v1 = 10
v2 = 2
print(v1+v2)
print(v1-v2)
print(v1*v2)
print(v1/v2)
# Out:
# 12
# 8
# 20
# 5.0

# %% [markdown]
# #2
# Crea dos listas con 3 nombres cada una llamadas grupo1 y grupo2.

# %%
grupo1 = ["juan","pedro","sergio"]
grupo2 = ["maria","jose","anacleta"]
print(grupo1)
print(grupo2)
# Out:
# ['juan', 'pedro', 'sergio']
# ['maria', 'jose', 'anacleta']

# %% [markdown]
# #3
# Crea una tercera lista llamada grupo3 con los últimos nombres de cada una de las listas grupo1 y grupo2 y elimina esos nombres de las listas originales.

# %%
grupo3 = []
grupo3.append(grupo1[2])
grupo3.append(grupo2[2])
print(grupo3)
# Out:
# ['sergio', 'anacleta']

# %%
print(grupo1)
grupo1.pop()
print(grupo1)

print(grupo2)
grupo2.pop()
print(grupo2)
# Out:
# ['juan', 'pedro', 'sergio']
# ['juan', 'pedro']
# ['maria', 'jose', 'anacleta']
# ['maria', 'jose']

# %% [markdown]
# #4
# Crea una lista llamada todos con todos los nombres de las listas.

# %%
todos = grupo1 + grupo2 + grupo3
print(todos)
# Out:
# ['juan', 'pedro', 'maria', 'jose', 'sergio', 'anacleta']

# %% [markdown]
# #5,6,7,8
# Crea un diccionario que tenga 3 pares de clave valor con países y capitales.
#
# Hace un print de los nombres de lo países.
#
# Mostrá los nombres de las capitales
#
# Agrega una par de país-capital

# %%
diccionario = {"Argentina":"Buenos Aires","Uruguay":"Montevideo","Peru":"Lima"}
print(diccionario.keys())
print(diccionario.values())
diccionario["Paraguay"] = "Asunsion"
diccionario.items()
# Out:
# dict_keys(['Argentina', 'Uruguay', 'Peru'])
# dict_values(['Buenos Aires', 'Montevideo', 'Lima'])
# dict_items([('Argentina', 'Buenos Aires'), ('Uruguay', 'Montevideo'), ('Peru', 'Lima'), ('Paraguay', 'Asunsion')])
