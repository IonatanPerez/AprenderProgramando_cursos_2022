# %%
import pandas as pd
data = pd.read_csv("/content/data_limpia_clase9(1).csv")
data
# Out:
#       Unnamed: 0  humedad  velocidad_viento_kmh  rumbo_viento_grados  \
# 0              0     0.92                 11.27                130.0
# 1              1     0.73                 20.93                330.0
# 2              2     0.97                  5.97                193.0
# 3              3     0.82                  3.22                300.0
# 4              4     0.60                 10.88                116.0
# ...          ...      ...                   ...                  ...
# 9982        9995     0.95                 10.24                 20.0
# 9983        9996     0.64                 11.04                 80.0
# 9984        9997     0.93                 11.04                269.0
# 9985        9998     0.78                  8.18                231.0
# 9986        9999     0.79                 14.25                131.0
#
#       visibilidad_km  presion_mbar  temperatura  lluvia_binarizada  \
# 0               8.05       1021.60        -0.56                  0
# ...

# %%
data.corr()
# Out:
#                       Unnamed: 0   humedad  velocidad_viento_kmh  \
# Unnamed: 0              1.000000  0.005234             -0.012047
# humedad                 0.005234  1.000000             -0.222410
# velocidad_viento_kmh   -0.012047 -0.222410              1.000000
# rumbo_viento_grados    -0.012130 -0.007605              0.108464
# visibilidad_km         -0.003734 -0.375690              0.100416
# presion_mbar            0.005619  0.041448             -0.267220
# temperatura            -0.006425 -0.629062              0.009777
# lluvia_binarizada      -0.004198 -0.224919              0.067215
# descripcion_Normal     -0.007086  0.210393              0.033914
# descripcion_Warm       -0.004813 -0.595640             -0.003859
#
#                       rumbo_viento_grados  visibilidad_km  presion_mbar  \
# Unnamed: 0                      -0.012130       -0.003734      0.005619
# humedad                         -0.007605       -0.375690      0.041448
# ...

# %%
data_seleccionada = data[['temperatura', 'humedad']]
data_seleccionada.head(20)
# Out:
#     temperatura  humedad
# 0         -0.56     0.92
# 1         21.11     0.73
# 2         16.60     0.97
# 3          1.60     0.82
# 4          2.19     0.60
# 5         27.54     0.32
# 6         19.98     0.84
# 7         11.11     0.86
# 8          8.41     0.73
# 9          1.70     0.81
# 10        -2.22     0.88
# 11        21.90     0.60
# 12        17.11     0.87
# 13        17.77     0.73
# 14        24.95     0.39
# 15        -2.71     0.92
# 16        18.89     0.78
# 17         4.33     0.82
# 18        23.89     0.54
# 19        -2.22     0.68

# %%
X = data['humedad']
y = data['temperatura']

# %%
import seaborn as sns     #mas rapido

# %%
sns.scatterplot(data = data, x='humedad', y='temperatura')

# %%
sns.scatterplot(data = data, x='humedad', y='temperatura', hue='lluvia_binarizada')  #tener mas variables mejora el programa.

# %%
sns.regplot(data = data, x='humedad', y='temperatura')  #sirve para visualizar, no para analizar.

# %%
#para entrenar un modelo hay que guardar datos que no se usaron en el modelo.
from sklearn.model_selection import train_test_split  #funcion que separa los datos en test y entrenamiento.

x_train, x_test, y_train, y_test = train_test_split(X,y, random_state = 24)
#random_state es una semilla para que te de un numero de grupo random

# %%
y_test
# Out:
# 5252     0.81
# 255     16.67
# 5348    12.06
# 7823    11.09
# 4848     9.39
#         ...
# 3146    17.28
# 9357     3.84
# 4943     1.13
# 9400     9.50
# 2165     1.02
# Name: temperatura, Length: 2497, dtype: float64

# %%
import numpy as np

x_train_m = x_train.to_numpy()

x_train = np.matrix(x_train_m.reshape(len(x_train_m),1))

x_train_m = x_train.to_numpy()

x_train_m = np.matrix(x_train_m.reshape(len(x_train_m),1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-cd8a8ff03561> in <module>()
#       1 import numpy as np
#       2
# ----> 3 x_train_m = x_train.to_numpy()
#       4
#       5 x_train = np.matrix(x_train_m.reshape(len(x_train_m),1))
#
# AttributeError: 'matrix' object has no attribute 'to_numpy'

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression()

modelo.fit(x_train, y_train)   #son los datos a entrenar.  #X es para muchas columnas.
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# LinearRegression()

# %%
modelo.coef_ #seria m en el grafico.
# Out:
# array([-30.76762427])

# %%
modelo.intercept_ #seria b en el grafico.
# Out:
# 34.47389203575493

# %%
sns.scatterplot(x=x_test_m, y=y_test_m)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-0ff9dfb77a64> in <module>()
# ----> 1 sns.scatterplot(x=x_test_m, y=y_test_m)
#
# NameError: name 'x_test_m' is not defined

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
r2
