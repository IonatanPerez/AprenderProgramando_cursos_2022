# %%
import matplotlib.pyplot as plt  
import seaborn as sns
import pandas as pd
data = pd.read_csv("/content/pokemon.csv.zip")
data
# Out:
#          nombre  indice_guia  resistencia  ataque  defensa tipo_primario  \
# 0     Bulbasaur            1        128.0   118.0    111.0         Grass
# 1       Ivysaur            2        155.0   151.0    143.0         Grass
# 2      Venusaur            3        190.0   198.0    189.0         Grass
# 3    Charmander            4        118.0   116.0     93.0          Fire
# 4    Charmeleon            5        151.0   158.0    126.0          Fire
# ..          ...          ...          ...     ...      ...           ...
# 644    Landorus          645        205.0   261.0    182.0        Ground
# 645      Kyurem          646        245.0   246.0    170.0        Dragon
# 646      Keldeo          647        209.0   260.0    192.0         Water
# 647    Meloetta          648        225.0   250.0    225.0        Normal
# 648    Genesect          649        174.0   252.0    199.0           Bug
#
#     tipo_secundario  max_salud  tasa_captura  tasa_escape  Weight  Height  \
# ...

# %%
data.shape
data.columns
# Out:
# Index(['nombre', 'indice_guia', 'resistencia', 'ataque', 'defensa',
#        'tipo_primario', 'tipo_secundario', 'max_salud', 'tasa_captura',
#        'tasa_escape', 'Weight', 'Height', 'Legendario', 'generacion',
#        'fuerza_combate'],
#       dtype='object')

# %%
data.rename(columns= {"Weight": "peso", "Height": "altura", "Legendario": "legendario"}, inplace= True)
data
# Out:
#          nombre  indice_guia  resistencia  ataque  defensa tipo_primario  \
# 0     Bulbasaur            1        128.0   118.0    111.0         Grass
# 1       Ivysaur            2        155.0   151.0    143.0         Grass
# 2      Venusaur            3        190.0   198.0    189.0         Grass
# 3    Charmander            4        118.0   116.0     93.0          Fire
# 4    Charmeleon            5        151.0   158.0    126.0          Fire
# ..          ...          ...          ...     ...      ...           ...
# 644    Landorus          645        205.0   261.0    182.0        Ground
# 645      Kyurem          646        245.0   246.0    170.0        Dragon
# 646      Keldeo          647        209.0   260.0    192.0         Water
# 647    Meloetta          648        225.0   250.0    225.0        Normal
# 648    Genesect          649        174.0   252.0    199.0           Bug
#
#     tipo_secundario  max_salud  tasa_captura  tasa_escape   peso  altura  \
# ...

# %%
data.drop(columns = 'indice_guia', inplace=True)

# %%
data.head()
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 0   Bulbasaur        128.0   118.0    111.0         Grass          Poison
# 1     Ivysaur        155.0   151.0    143.0         Grass          Poison
# 2    Venusaur        190.0   198.0    189.0         Grass          Poison
# 3  Charmander        118.0   116.0     93.0          Fire            None
# 4  Charmeleon        151.0   158.0    126.0          Fire            None
#
#    max_salud  tasa_captura  tasa_escape   peso  altura legendario  generacion  \
# 0      113.0          0.20         0.10    6.9     0.7         No           1
# 1      134.0          0.10         0.07   13.0     1.0         No           1
# 2      162.0          0.05         0.05  100.0     2.0         No           1
# 3      105.0          0.20         0.10    8.5     0.6         No           1
# 4      131.0          0.10         0.07   19.0     1.1         No           1
#
#    fuerza_combate
# 0            1115
# ...

# %%
data.isna().sum()
# Out:
# nombre             0
# resistencia        5
# ataque             5
# defensa            5
# tipo_primario      5
# tipo_secundario    5
# max_salud          5
# tasa_captura       5
# tasa_escape        5
# peso               0
# altura             4
# legendario         1
# generacion         0
# fuerza_combate     0
# dtype: int64

# %%
data.dtypes
# Out:
# nombre              object
# resistencia        float64
# ataque             float64
# defensa            float64
# tipo_primario       object
# tipo_secundario     object
# max_salud          float64
# tasa_captura       float64
# tasa_escape        float64
# peso               float64
# altura             float64
# legendario          object
# generacion           int64
# fuerza_combate       int64
# dtype: object

# %%
nulo_legen = data["legendario"].isnull()
data.loc[nulo_legen]
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 162  Hoothoot        155.0    67.0     88.0        Normal          Flying
#
#      max_salud  tasa_captura  tasa_escape  peso  altura legendario  \
# 162      134.0           0.5         0.15  21.2    0.71        NaN
#
#      generacion  fuerza_combate
# 162           2             677

# %%
data['legendario'].value_counts()
# Out:
# No    609
# Sí     39
# Name: legendario, dtype: int64

# %%
data.loc[nulo_legen, 'legendario']
# Out:
# 162    NaN
# Name: legendario, dtype: object

# %%
data.loc[nulo_legen, 'legendario'] = 'no'
data.loc[nulo_legen]
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 162  Hoothoot        155.0    67.0     88.0        Normal          Flying
#
#      max_salud  tasa_captura  tasa_escape  peso  altura legendario  \
# 162      134.0           0.5         0.15  21.2    0.71         no
#
#      generacion  fuerza_combate
# 162           2             677

# %%
data.isnull().sum()
# Out:
# nombre             0
# resistencia        5
# ataque             5
# defensa            5
# tipo_primario      5
# tipo_secundario    5
# max_salud          5
# tasa_captura       5
# tasa_escape        5
# peso               0
# altura             4
# legendario         0
# generacion         0
# fuerza_combate     0
# dtype: int64

# %%
data.dropna()
# Out:
#          nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 0     Bulbasaur        128.0   118.0    111.0         Grass          Poison
# 1       Ivysaur        155.0   151.0    143.0         Grass          Poison
# 2      Venusaur        190.0   198.0    189.0         Grass          Poison
# 3    Charmander        118.0   116.0     93.0          Fire            None
# 4    Charmeleon        151.0   158.0    126.0          Fire            None
# ..          ...          ...     ...      ...           ...             ...
# 644    Landorus        205.0   261.0    182.0        Ground          Flying
# 645      Kyurem        245.0   246.0    170.0        Dragon             Ice
# 646      Keldeo        209.0   260.0    192.0         Water        Fighting
# 647    Meloetta        225.0   250.0    225.0        Normal         Psychic
# 648    Genesect        174.0   252.0    199.0           Bug           Steel
#
# ...

# %%
data[data['resistencia'].isna()]
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 175   Togetic          NaN     NaN      NaN           NaN             NaN
# 248     Lugia          NaN     NaN      NaN           NaN             NaN
# 345   Cradily          NaN     NaN      NaN           NaN             NaN
# 568  Garbodor          NaN     NaN      NaN           NaN             NaN
# 580    Swanna          NaN     NaN      NaN           NaN             NaN
#
#      max_salud  tasa_captura  tasa_escape   peso  altura legendario  \
# 175        NaN           NaN          NaN    3.2    0.61         No
# 248        NaN           NaN          NaN  216.0    5.21         Sí
# 345        NaN           NaN          NaN   60.4    1.50         No
# 568        NaN           NaN          NaN  107.3    1.90         No
# 580        NaN           NaN          NaN   24.2    1.30         No
#
#      generacion  fuerza_combate
# 175           2            1708
# 248           2            3703
# ...

# %%
data[data['ataque'].isna()]
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 175   Togetic          NaN     NaN      NaN           NaN             NaN
# 248     Lugia          NaN     NaN      NaN           NaN             NaN
# 345   Cradily          NaN     NaN      NaN           NaN             NaN
# 568  Garbodor          NaN     NaN      NaN           NaN             NaN
# 580    Swanna          NaN     NaN      NaN           NaN             NaN
#
#      max_salud  tasa_captura  tasa_escape   peso  altura legendario  \
# 175        NaN           NaN          NaN    3.2    0.61         No
# 248        NaN           NaN          NaN  216.0    5.21         Sí
# 345        NaN           NaN          NaN   60.4    1.50         No
# 568        NaN           NaN          NaN  107.3    1.90         No
# 580        NaN           NaN          NaN   24.2    1.30         No
#
#      generacion  fuerza_combate
# 175           2            1708
# 248           2            3703
# ...

# %%
data.isnull().sum()
# Out:
# nombre             0
# resistencia        5
# ataque             5
# defensa            5
# tipo_primario      5
# tipo_secundario    5
# max_salud          5
# tasa_captura       5
# tasa_escape        5
# peso               0
# altura             4
# legendario         0
# generacion         0
# fuerza_combate     0
# dtype: int64

# %%
data[data['altura'].isna()]
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 123      Jynx        163.0   223.0    151.0           Ice         Psychic
# 128  Magikarp         85.0    29.0     85.0         Water            None
# 352   Shuppet        127.0   138.0     65.0         Ghost            None
# 435   Bronzor        149.0    43.0    154.0         Steel         Psychic
#
#      max_salud  tasa_captura  tasa_escape  peso  altura legendario  \
# 123      140.0           0.3         0.09  40.6     NaN         No
# 128       79.0           0.7         0.15  10.0     NaN         No
# 352      112.0           0.4         0.10   2.3     NaN         No
# 435      129.0           0.5         0.10  60.5     NaN         No
#
#      generacion  fuerza_combate
# 123           1            2555
# 128           1             274
# 352           3            1018
# 435           4             603

# %%
data['altura'].mean()
# Out:
# 1.1505891472868215

# %%
altura_prom = data['altura'].mean()
print(altura_prom)
# Out:
# 1.1505891472868215

# %%
sns.distplot(data['altura'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
nan = data['altura'].isna()
datos_nan = data.loc[nan]

display(datos_nan['altura'])

data.loc[nan, 'altura'] = altura_prom

data[nan]
# Out:
# 123   NaN
# 128   NaN
# 352   NaN
# 435   NaN
# Name: altura, dtype: float64
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 123      Jynx        163.0   223.0    151.0           Ice         Psychic
# 128  Magikarp         85.0    29.0     85.0         Water            None
# 352   Shuppet        127.0   138.0     65.0         Ghost            None
# 435   Bronzor        149.0    43.0    154.0         Steel         Psychic
#
#      max_salud  tasa_captura  tasa_escape  peso    altura legendario  \
# 123      140.0           0.3         0.09  40.6  1.150589         No
# 128       79.0           0.7         0.15  10.0  1.150589         No
# 352      112.0           0.4         0.10   2.3  1.150589         No
# 435      129.0           0.5         0.10  60.5  1.150589         No
#
#      generacion  fuerza_combate
# 123           1            2555
# 128           1             274
# 352           3            1018
# 435           4             603

# %%
data.isnull().sum()
# Out:
# nombre             0
# resistencia        5
# ataque             5
# defensa            5
# tipo_primario      5
# tipo_secundario    5
# max_salud          5
# tasa_captura       5
# tasa_escape        5
# peso               0
# altura             0
# legendario         0
# generacion         0
# fuerza_combate     0
# dtype: int64

# %%
data.shape
# Out:
# (649, 14)

# %%
data.dropna(inplace=True)
data
# Out:
#          nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 0     Bulbasaur        128.0   118.0    111.0         Grass          Poison
# 1       Ivysaur        155.0   151.0    143.0         Grass          Poison
# 2      Venusaur        190.0   198.0    189.0         Grass          Poison
# 3    Charmander        118.0   116.0     93.0          Fire            None
# 4    Charmeleon        151.0   158.0    126.0          Fire            None
# ..          ...          ...     ...      ...           ...             ...
# 644    Landorus        205.0   261.0    182.0        Ground          Flying
# 645      Kyurem        245.0   246.0    170.0        Dragon             Ice
# 646      Keldeo        209.0   260.0    192.0         Water        Fighting
# 647    Meloetta        225.0   250.0    225.0        Normal         Psychic
# 648    Genesect        174.0   252.0    199.0           Bug           Steel
#
# ...

# %%
data.isnull().sum()
# Out:
# nombre             0
# resistencia        0
# ataque             0
# defensa            0
# tipo_primario      0
# tipo_secundario    0
# max_salud          0
# tasa_captura       0
# tasa_escape        0
# peso               0
# altura             0
# legendario         0
# generacion         0
# fuerza_combate     0
# dtype: int64

# %%
data
# Out:
#          nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 0     Bulbasaur        128.0   118.0    111.0         Grass          Poison
# 1       Ivysaur        155.0   151.0    143.0         Grass          Poison
# 2      Venusaur        190.0   198.0    189.0         Grass          Poison
# 3    Charmander        118.0   116.0     93.0          Fire            None
# 4    Charmeleon        151.0   158.0    126.0          Fire            None
# ..          ...          ...     ...      ...           ...             ...
# 644    Landorus        205.0   261.0    182.0        Ground          Flying
# 645      Kyurem        245.0   246.0    170.0        Dragon             Ice
# 646      Keldeo        209.0   260.0    192.0         Water        Fighting
# 647    Meloetta        225.0   250.0    225.0        Normal         Psychic
# 648    Genesect        174.0   252.0    199.0           Bug           Steel
#
# ...

# %%
sns.countplot(data['legendario'])
data['legendario'].unique()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# array(['No', 'Sí', 'no'], dtype=object)

# %%
data.isnull().sum()
# Out:
# nombre             0
# resistencia        0
# ataque             0
# defensa            0
# tipo_primario      0
# tipo_secundario    0
# max_salud          0
# tasa_captura       0
# tasa_escape        0
# peso               0
# altura             0
# legendario         0
# generacion         0
# fuerza_combate     0
# dtype: int64

# %%
data["legendario"].value_counts()
# Out:
# No    605
# Sí     38
# no      1
# Name: legendario, dtype: int64

# %%
dict_legen={'Sí':1, 'No':0,'no':0}
data['legendario'].map(dict_legen)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 644    1
# 645    1
# 646    0
# 647    0
# 648    0
# Name: legendario, Length: 644, dtype: int64

# %%
data['legendario_bin'] = data['legendario'].map(dict_legen)
data.tail()
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 644  Landorus        205.0   261.0    182.0        Ground          Flying
# 645    Kyurem        245.0   246.0    170.0        Dragon             Ice
# 646    Keldeo        209.0   260.0    192.0         Water        Fighting
# 647  Meloetta        225.0   250.0    225.0        Normal         Psychic
# 648  Genesect        174.0   252.0    199.0           Bug           Steel
#
#      max_salud  tasa_captura  tasa_escape   peso  altura legendario  \
# 644      173.0          0.02         0.01   68.0     1.5         Sí
# 645      205.0          0.02         0.01  325.0     3.0         Sí
# 646      177.0          0.02         0.01   48.5     1.4         No
# 647      189.0          0.02         0.01    6.5     0.6         No
# 648      149.0          0.02         0.01   82.5     1.5         No
#
#      generacion  fuerza_combate  legendario_bin
# 644           5            3588               1
# ...

# %%
data.drop(columns=['legendario'], inplace=True)
data.head()
# Out:
#        nombre  resistencia  ataque  defensa tipo_primario tipo_secundario  \
# 0   Bulbasaur        128.0   118.0    111.0         Grass          Poison
# 1     Ivysaur        155.0   151.0    143.0         Grass          Poison
# 2    Venusaur        190.0   198.0    189.0         Grass          Poison
# 3  Charmander        118.0   116.0     93.0          Fire            None
# 4  Charmeleon        151.0   158.0    126.0          Fire            None
#
#    max_salud  tasa_captura  tasa_escape   peso  altura  generacion  \
# 0      113.0          0.20         0.10    6.9     0.7           1
# 1      134.0          0.10         0.07   13.0     1.0           1
# 2      162.0          0.05         0.05  100.0     2.0           1
# 3      105.0          0.20         0.10    8.5     0.6           1
# 4      131.0          0.10         0.07   19.0     1.1           1
#
#    fuerza_combate  legendario_bin
# 0            1115               0
# 1            1699               0
# ...

# %%
data["tipo_primario"].value_counts()
# Out:
# Water       99
# Normal      89
# Grass       61
# Bug         60
# Psychic     43
# Fire        39
# Electric    33
# Rock        32
# Ground      30
# Poison      25
# Dark        25
# Fighting    22
# Ice         21
# Dragon      20
# Ghost       19
# Steel       18
# Fairy        7
# Flying       1
# Name: tipo_primario, dtype: int64

# %%
data['tipo_secundario'].value_counts()
# Out:
# None        339
# Flying       78
# Poison       31
# Ground       28
# Psychic      24
# Steel        19
# Fighting     18
# Dark         14
# Fairy        14
# Rock         14
# Grass        13
# Water         9
# Fire          9
# Dragon        9
# Ghost         8
# Ice           8
# Electric      6
# Bug           3
# Name: tipo_secundario, dtype: int64

# %%
datos_nan.to_csv('data_limpia_tarea.csv')

# %%
import seaborn as sns

# %%
data_selec = data[['fuerza_combate', 'defensa']]
data_selec.head(10)
# Out:
#    fuerza_combate  defensa
# 0            1115    111.0
# 1            1699    143.0
# 2            2720    189.0
# 3             980     93.0
# 4            1653    126.0
# 5            2889    173.0
# 6             946    121.0
# 7            1488    155.0
# 8            2466    207.0
# 9             437     55.0

# %%
sns.scatterplot(data = data, x='defensa', y='fuerza_combate')

# %%
sns.regplot(data = data, x='defensa', y='fuerza_combate')

# %%
from sklearn.model_selection import train_test_split

# %%
X=data['defensa']
y=data['fuerza_combate']

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, random_state = 24)

# %%
x_train
# Out:
# 316    159.0
# 125    154.0
# 618     98.0
# 626     97.0
# 42     112.0
#        ...
# 145    181.0
# 404    156.0
# 346    100.0
# 193     66.0
# 421    105.0
# Name: defensa, Length: 483, dtype: float64

# %%
import numpy as np
x_train_m = x_train.to_numpy()

x_train_m = np.matrix(x_train_m.reshape(len(x_train_m),1))

x_test_m = x_test.to_numpy()
x_test_m = np.matrix(x_test_m.reshape(len(x_test_m),1))
#solo se hace si hay una columna

# %%
from sklearn.linear_model import LinearRegression

modelo = LinearRegression(fit_intercept=True)

modelo.fit(x_train_m,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,
# LinearRegression()

# %%
print (modelo.coef_)
modelo.intercept_
# Out:
# [14.04506444]
# -17.123383549424716

# %%
plt.figure(figsize = (10,10))
plt.scatter(x_test, y_test, color = 'b', label = 'Datos de testeo')
y_pred = modelo.predict(x_test_m)
plt.scatter(x_test, y_pred, color = 'g', label = 'Datos predichos')
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:598: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   FutureWarning,

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.313954038016369

# %%
X_limpia = X.drop(columns= ['nombre', 'tipo_primario', 'tipo_secundario'])
X_limpia
# Out:
# 0      111.0
# 1      143.0
# 2      189.0
# 3       93.0
# 4      126.0
#        ...
# 644    182.0
# 645    170.0
# 646    192.0
# 647    225.0
# 648    199.0
# Name: defensa, Length: 644, dtype: float64
