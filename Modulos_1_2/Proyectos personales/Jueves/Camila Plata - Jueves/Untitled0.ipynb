# %%
#pandas
#data.columns - muestra los nombres de las columnas

# %%
#data['nomre de columna'] -muestras los registros de la columna

# %%
#data['nomre de columna'].sum() - suma todos los registros de esa columna

# %%
anio_seleccionado =2017
data[nombre columna]==anio_seleccionado

marco_seleccionado = data[nombre columna]==anio_seleccionado
print(marco_seleccionado)

# %%
data[].unique() - muestra una sola vez

# %%
#stakoverflow - web

# %%
# .mean - promedio

# %%
#cheatsheets
