# %%
lista_de_presentes=["Camila 1", "Camila 2", "Breider", "Ayax", "Alan", "Sergio"]

lista_de_inscriptos=["Camila 1", "Camila 2", "Breider", "Ayax", "Alan", "Marco"]

# %% [markdown]
# Solucion:

# %%
lista_de_presentes=["Camila 1","Camila 2","Breider", "Ayax", "Alan", "Sergio"]
if "Camila 1" in lista_de_presentes
  print ("Camila 1 esta presente")
else:
  print ("Camila 1 esta ausente")

# %%
#como se comparan cosas:
primera_cosa= 4
segunda_cosa= 5

primera_cosa +1 == segunda_cosa

# %%
# input() = se usa para escribir 
in #se usa para saber si algo esta en una "cosa"
for # recorre una lista 
def # sirve para definir una funcion
len #cuenta las cosas
