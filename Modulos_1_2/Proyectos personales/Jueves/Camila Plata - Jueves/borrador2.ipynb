# %% [markdown]
# Ejercicios Tipos de datos
# Hacer una lista que contenga 3 materias de la escuela
#
# Eliminar el primer registro de la lista
#
# Agregar una materia más al final
#
# Seleccionar el segundo elemento de la lista
#
# Crear un diccionario con las materias y el nombre del/la profesor/a
#
# Agregar una materia y un/a profesora/
#
# Eliminar una materia y un/a profesor/a

# %%
lista_de_materias = ["quimica", "termodinamica", "lengua"]
lista_de_materias
# Out:
# ['quimica', 'termodinamica', 'lengua']

# %%
lista_de_materias[1]
# Out:
# 'termodinamica'

# %%
diccionario_materias = {"matematica": "perez"}
diccionario_materias
# Out:
# {'matematica': 'perez'}

# %%
diccionario_materias["matematica"]="jose"
diccionario_materias
# Out:
# {'matematica': 'jose'}

# %%
#para eliminar 
#diccionario_materias.pop("lengua")

# %%
#estructura de control

num1 = 3
num2 = 5

if num1==num2:
  print("son iguales")
else:
  print("son distintos")
# Out:
# son distintos

# %%
lista_numero = [2,4,5]

for i in lista_numero:
  print(i+2)
#revisar
# Out:
# 4
# 6
# 7

# %%
nombre = "tamara"
nombre2= "valeria"
nombre==nombre2
# Out:
# False

# %%
#crear una funcion  que divida dos num que recibe parametros

def funcion_numeros(num1, num2):
  return num1/num2

# %%
funcion_numeros(8,4)

# %% [markdown]
# ir a w3schook
# librerias-buscar
# ir a kaggle dataset
# ir a panda
#
# csv= tipo de archico separado por comas
#
# columnas=registros
#
# dataframe: marco de datos

# %%
#importamos la librerua

import pandas as pd


from google.colab import files
import io

# %%
filesUploaded = files.

# %% [markdown]
# crear
#
# data=pd.read.csv

# %%
#para crear un objeto data
data=pd.read.csv

# %% [markdown]
# columna:series
#
# cada columna tiene un tipo de dato (float, int, string)
#
# filas=horizontal
# columnas=vetical
#
# diccionario: {}
# lista: []

# %%
#cuantas coluna tiene el datafree

data.head(2)

# %%
data.shape

# %%
data[]

# %% [markdown]
# dataset:tabla, conjunto de tabla
# cada tabla es un registro
#
# nan=nulo

# %%
import pandas as pd
data =pd.read.csv("url")
