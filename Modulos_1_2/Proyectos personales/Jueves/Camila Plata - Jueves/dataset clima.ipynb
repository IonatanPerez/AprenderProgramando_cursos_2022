# %%
import matplotlib.pyplot as plt  
import seaborn as sns
import pandas as pd
data = pd.read_csv("/content/Dataset Clima.csv")
data
# Out:
#         id  Humidity  Wind_Speed_kmh  rumbo_viento_grados  visibilidad_km  \
# 0        0      0.92           11.27                130.0            8.05
# 1        1      0.73           20.93                330.0           16.10
# 2        2      0.97            5.97                193.0           14.91
# 3        3      0.82            3.22                300.0           16.10
# 4        4      0.60           10.88                116.0            9.98
# ...    ...       ...             ...                  ...             ...
# 9995  9995      0.95           10.24                 20.0            4.01
# 9996  9996      0.64           11.04                 80.0            9.98
# 9997  9997      0.93           11.04                269.0           14.91
# 9998  9998      0.78            8.18                231.0            7.82
# 9999  9999      0.79           14.25                131.0           10.26
#
#       presion_mbar lluvia descripcion  temperatura
# ...

# %%
data.shape
data.columns
# Out:
# Index(['id', 'Humidity', 'Wind_Speed_kmh', 'rumbo_viento_grados',
#        'visibilidad_km', 'presion_mbar', 'lluvia', 'descripcion',
#        'temperatura'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                       int64
# Humidity               float64
# Wind_Speed_kmh         float64
# rumbo_viento_grados    float64
# visibilidad_km         float64
# presion_mbar           float64
# lluvia                  object
# descripcion             object
# temperatura            float64
# dtype: object

# %%
data['descripcion'].isna().sum()
data[data['descripcion'].isna()]
# Out:
#         id  Humidity  Wind_Speed_kmh  rumbo_viento_grados  visibilidad_km  \
# 549    549      0.55           20.46                160.0           10.21
# 1485  1485      0.56           16.04                 33.0           10.35
# 2224  2224      0.48           11.27                120.0            9.98
# 3485  3485      0.45           13.78                341.0           16.10
# 5382  5382      0.92            4.73                170.0            3.53
# 6582  6582      0.65           27.10                319.0            9.98
# 7815  7815       NaN             NaN                  NaN             NaN
# 9614  9614      0.82           11.27                 10.0           16.10
#
#       presion_mbar lluvia descripcion  temperatura
# 549        1020.71     si         NaN         8.91
# 1485       1021.43     si         NaN         2.83
# 2224       1011.10     si         NaN        16.11
# 3485       1019.04     si         NaN        23.79
# ...

# %%
data.isnull().sum()
# Out:
# id                     0
# Humidity               5
# Wind_Speed_kmh         5
# rumbo_viento_grados    5
# visibilidad_km         5
# presion_mbar           9
# lluvia                 1
# descripcion            8
# temperatura            0
# dtype: int64

# %%
dict_renombrar= {"Humidity":"humedad", "Wind_Speed_kmh":"velocidad_viento_kmh"}

data.rename(columns=dict_renombrar, inplace=True)
data.head()
# Out:
#    id  humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 0   0     0.92                 11.27                130.0            8.05
# 1   1     0.73                 20.93                330.0           16.10
# 2   2     0.97                  5.97                193.0           14.91
# 3   3     0.82                  3.22                300.0           16.10
# 4   4     0.60                 10.88                116.0            9.98
#
#    presion_mbar lluvia descripcion  temperatura
# 0       1021.60     no        Cold        -0.56
# 1       1017.00     si        Warm        21.11
# 2       1013.99     si      Normal        16.60
# 3       1031.59     si        Cold         1.60
# 4       1020.88     si        Cold         2.19

# %%
data.describe()
# Out:
#                 id      humedad  velocidad_viento_kmh  rumbo_viento_grados  \
# count  10000.00000  9995.000000           9995.000000          9995.000000
# mean    4999.50000     0.735334             10.813809           185.947274
# std     2886.89568     0.195459              6.972945           107.477976
# min        0.00000     0.000000              0.000000             0.000000
# 25%     2499.75000     0.600000              5.750000           112.000000
# 50%     4999.50000     0.780000              9.930000           179.000000
# 75%     7499.25000     0.900000             14.100000           290.000000
# max     9999.00000     1.000000             53.240000           359.000000
#
#        visibilidad_km  presion_mbar   temperatura
# count     9995.000000   9991.000000  10000.000000
# mean        10.372852   1004.884407     11.857190
# std          4.179357    109.665639      9.512215
# min          0.000000      0.000000    -21.820000
# ...

# %%
data.corr()
# Out:
#                             id   humedad  velocidad_viento_kmh  \
# id                    1.000000  0.005614             -0.012223
# humedad               0.005614  1.000000             -0.222691
# velocidad_viento_kmh -0.012223 -0.222691              1.000000
# rumbo_viento_grados  -0.012235 -0.007590              0.108552
# visibilidad_km       -0.003619 -0.375662              0.100517
# presion_mbar          0.001109 -0.011142             -0.051101
# temperatura          -0.006969 -0.628784              0.009679
#
#                       rumbo_viento_grados  visibilidad_km  presion_mbar  \
# id                              -0.012235       -0.003619      0.001109
# humedad                         -0.007590       -0.375662     -0.011142
# velocidad_viento_kmh             0.108552        0.100517     -0.051101
# rumbo_viento_grados              1.000000        0.052067     -0.005622
# visibilidad_km                   0.052067        1.000000      0.066664
# ...

# %%
sns.heatmap(abs(data.corr()), annot=True)

# %%
data["temperatura"].min()
# Out:
# -21.82

# %%
data["temperatura"].max()
# Out:
# 38.84

# %%
data["temperatura"].mean()
# Out:
# 11.85718999999998

# %%
sns.displot(data["temperatura"])

# %%
data.drop(columns="id", inplace=True)

# %%
data.head()
# Out:
#    humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 0     0.92                 11.27                130.0            8.05
# 1     0.73                 20.93                330.0           16.10
# 2     0.97                  5.97                193.0           14.91
# 3     0.82                  3.22                300.0           16.10
# 4     0.60                 10.88                116.0            9.98
#
#    presion_mbar lluvia descripcion  temperatura
# 0       1021.60     no        Cold        -0.56
# 1       1017.00     si        Warm        21.11
# 2       1013.99     si      Normal        16.60
# 3       1031.59     si        Cold         1.60
# 4       1020.88     si        Cold         2.19

# %%
data["descripcion"].unique()
# Out:
# array(['Cold', 'Warm', 'Normal', nan], dtype=object)

# %%
data["descripcion"].value_counts()
# Out:
# Normal    4989
# Warm      2506
# Cold      2497
# Name: descripcion, dtype: int64

# %%
sns.countplot(data["descripcion"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data["lluvia"].unique()
# Out:
# array(['no', 'si', nan], dtype=object)

# %%
data["lluvia"].value_counts()
# Out:
# si    8911
# no    1088
# Name: lluvia, dtype: int64

# %%
sns.countplot(data["lluvia"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.to_csv("data_clima_clase1.csv")

# %%
data.isna().sum()
mascara_humedad_isna = data["humedad"].isna()
data[mascara_humedad_isna]
# Out:
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 568       NaN                   NaN                  NaN             NaN
# 2548      NaN                   NaN                  NaN             NaN
# 3545      NaN                   NaN                  NaN             NaN
# 6580      NaN                   NaN                  NaN             NaN
# 7815      NaN                   NaN                  NaN             NaN
#
#       presion_mbar lluvia descripcion  temperatura
# 568            NaN     si      Normal        16.07
# 2548           NaN     si        Warm        27.76
# 3545           NaN     si      Normal        17.74
# 6580           NaN     si        Warm        22.97
# 7815           NaN     si         NaN         0.98

# %%
nulo_visibilidad = data["visibilidad_km"].isnull()
nulo_visibilidad
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: visibilidad_km, Length: 10000, dtype: bool

# %%
data.loc[nulo_visibilidad]
# Out:
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 568       NaN                   NaN                  NaN             NaN
# 2548      NaN                   NaN                  NaN             NaN
# 3545      NaN                   NaN                  NaN             NaN
# 6580      NaN                   NaN                  NaN             NaN
# 7815      NaN                   NaN                  NaN             NaN
#
#       presion_mbar lluvia descripcion  temperatura
# 568            NaN     si      Normal        16.07
# 2548           NaN     si        Warm        27.76
# 3545           NaN     si      Normal        17.74
# 6580           NaN     si        Warm        22.97
# 7815           NaN     si         NaN         0.98

# %%
data.dropna(axis=0, thresh=5, inplace=True)

# %%
data.loc[nulo_visibilidad]
# Out:
# Empty DataFrame
# Columns: [humedad, velocidad_viento_kmh, rumbo_viento_grados, visibilidad_km, presion_mbar, lluvia, descripcion, temperatura]
# Index: []

# %%
print(data.shape)
data.isnull().sum()
# Out:
# (9995, 8)
# humedad                 0
# velocidad_viento_kmh    0
# rumbo_viento_grados     0
# visibilidad_km          0
# presion_mbar            4
# lluvia                  1
# descripcion             7
# temperatura             0
# dtype: int64

# %%
nulo_lluvia = data["lluvia"].isnull()
nulo_lluvia
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: lluvia, Length: 9995, dtype: bool

# %%
data.loc[nulo_lluvia]
# Out:
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 1862     0.97                  9.58                299.0           11.27
#
#       presion_mbar lluvia descripcion  temperatura
# 1862       1003.99    NaN      Normal        17.64

# %%
data["lluvia"].value_counts()
# Out:
# si    8906
# no    1088
# Name: lluvia, dtype: int64

# %%
data.loc[nulo_lluvia, "lluvia"]
# Out:
# 1862    NaN
# Name: lluvia, dtype: object

# %%
data.loc[nulo_lluvia, "lluvia"] = "si"
data.loc[nulo_lluvia]
# Out:
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 1862     0.97                  9.58                299.0           11.27
#
#       presion_mbar lluvia descripcion  temperatura
# 1862       1003.99     si      Normal        17.64

# %%
print(data["lluvia"].value_counts())
data.isnull().sum()
# Out:
# si    8907
# no    1088
# Name: lluvia, dtype: int64
# humedad                 0
# velocidad_viento_kmh    0
# rumbo_viento_grados     0
# visibilidad_km          0
# presion_mbar            4
# lluvia                  0
# descripcion             7
# temperatura             0
# dtype: int64

# %%
data.isna().sum()
# Out:
# humedad                 0
# velocidad_viento_kmh    0
# rumbo_viento_grados     0
# visibilidad_km          0
# presion_mbar            4
# lluvia                  0
# descripcion             7
# temperatura             0
# dtype: int64

# %%
data.dropna()
# Out:
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 0        0.92                 11.27                130.0            8.05
# 1        0.73                 20.93                330.0           16.10
# 2        0.97                  5.97                193.0           14.91
# 3        0.82                  3.22                300.0           16.10
# 4        0.60                 10.88                116.0            9.98
# ...       ...                   ...                  ...             ...
# 9995     0.95                 10.24                 20.0            4.01
# 9996     0.64                 11.04                 80.0            9.98
# 9997     0.93                 11.04                269.0           14.91
# 9998     0.78                  8.18                231.0            7.82
# 9999     0.79                 14.25                131.0           10.26
#
#       presion_mbar lluvia descripcion  temperatura
# ...

# %%
data.isna().sum()
# Out:
# humedad                 0
# velocidad_viento_kmh    0
# rumbo_viento_grados     0
# visibilidad_km          0
# presion_mbar            4
# lluvia                  0
# descripcion             7
# temperatura             0
# dtype: int64

# %%
data[data['presion_mbar'].isna()]
# Out:
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 1253     0.42                  9.77                138.0           10.35
# 4135     0.48                 25.89                302.0           10.58
# 5352     0.92                  9.60                154.0           14.59
# 8128     0.35                  4.80                 50.0            9.98
#
#       presion_mbar lluvia descripcion  temperatura
# 1253           NaN     si      Normal        13.98
# 4135           NaN     si      Normal        17.00
# 5352           NaN     si        Cold         3.51
# 8128           NaN     si        Warm        27.20

# %%
valor_promedio = data['presion_mbar'].mean()
print (valor_promedio)
# Out:
# 1004.8844069662739

# %%
sns.distplot(data['presion_mbar'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
data['presion_mbar']<800
data[data['presion_mbar']<800]
# Out:
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 147      0.72                 14.10                232.0            0.00
# 223      0.81                 11.27                140.0            8.05
# 503      0.66                 24.01                 20.0            9.98
# 512      0.48                  8.65                 65.0           11.27
# 523      0.73                 11.40                319.0           11.27
# ...       ...                   ...                  ...             ...
# 9768     0.69                 21.94                359.0           11.27
# 9844     0.86                 15.86                359.0           11.21
# 9877     0.36                 14.59                 91.0            9.98
# 9931     0.71                  5.06                243.0            7.91
# 9950     0.72                  8.05                320.0            7.08
#
#       presion_mbar lluvia descripcion  temperatura
# ...

# %%
data_sin_ceros = data[data['presion_mbar'] > 800]
promedio_presion = data_sin_ceros['presion_mbar'].mean()
print (promedio_presion)
data_sin_ceros
# Out:
# 1016.7915849706342
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 0        0.92                 11.27                130.0            8.05
# 1        0.73                 20.93                330.0           16.10
# 2        0.97                  5.97                193.0           14.91
# 3        0.82                  3.22                300.0           16.10
# 4        0.60                 10.88                116.0            9.98
# ...       ...                   ...                  ...             ...
# 9995     0.95                 10.24                 20.0            4.01
# 9996     0.64                 11.04                 80.0            9.98
# 9997     0.93                 11.04                269.0           14.91
# 9998     0.78                  8.18                231.0            7.82
# 9999     0.79                 14.25                131.0           10.26
#
#       presion_mbar lluvia descripcion  temperatura
# ...

# %%
filtro = data['presion_mbar'].isna()
datos_filtrados = data.loc[filtro]

display (datos_filtrados['presion_mbar'])

data.loc[filtro, 'presion_mbar'] = promedio_presion


data[filtro]
# Out:
# 1253   NaN
# 4135   NaN
# 5352   NaN
# 8128   NaN
# Name: presion_mbar, dtype: float64
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 1253     0.42                  9.77                138.0           10.35
# 4135     0.48                 25.89                302.0           10.58
# 5352     0.92                  9.60                154.0           14.59
# 8128     0.35                  4.80                 50.0            9.98
#
#       presion_mbar lluvia descripcion  temperatura
# 1253   1016.791585     si      Normal        13.98
# 4135   1016.791585     si      Normal        17.00
# 5352   1016.791585     si        Cold         3.51
# 8128   1016.791585     si        Warm        27.20

# %%
filtro = data['presion_mbar'] < 800
datos_filtrados = data.loc[filtro]

display (datos_filtrados['presion_mbar'])

data.loc[filtro, 'presion_mbar'] = promedio_presion


data[filtro]
# Out:
# 147     0.0
# 223     0.0
# 503     0.0
# 512     0.0
# 523     0.0
#        ...
# 9768    0.0
# 9844    0.0
# 9877    0.0
# 9931    0.0
# 9950    0.0
# Name: presion_mbar, Length: 117, dtype: float64
#       humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 147      0.72                 14.10                232.0            0.00
# 223      0.81                 11.27                140.0            8.05
# 503      0.66                 24.01                 20.0            9.98
# 512      0.48                  8.65                 65.0           11.27
# 523      0.73                 11.40                319.0           11.27
# ...       ...                   ...                  ...             ...
# 9768     0.69                 21.94                359.0           11.27
# 9844     0.86                 15.86                359.0           11.21
# 9877     0.36                 14.59                 91.0            9.98
# ...

# %%
data.dropna(inplace=True)

data.isna().sum()
data.shape
# Out:
# (9988, 8)

# %%
sns.countplot(data['lluvia'])
data['lluvia'].unique()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# array(['no', 'si'], dtype=object)

# %%
data['lluvia_binarizada'] = data['lluvia'].apply(cambiar_valor)
data.head()
# Out:
#    humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 0     0.92                 11.27                130.0            8.05
# 1     0.73                 20.93                330.0           16.10
# 2     0.97                  5.97                193.0           14.91
# 3     0.82                  3.22                300.0           16.10
# 4     0.60                 10.88                116.0            9.98
#
#    presion_mbar lluvia descripcion  temperatura  lluvia_binarizada
# 0       1021.60     no        Cold        -0.56                  0
# 1       1017.00     si        Warm        21.11                  1
# 2       1013.99     si      Normal        16.60                  1
# 3       1031.59     si        Cold         1.60                  1
# 4       1020.88     si        Cold         2.19                  1

# %%
def cambiar_valor(valor):
  if valor == 'si':
    return 1
  else:
    return 0

# %%
data['lluvia'].apply(lambda x: 1 if x=='si' else 0)

dict_lluvia = {'si':1, 'no':0}

data['lluvia'].map(dict_lluvia)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    1
# 9998    1
# 9999    1
# Name: lluvia, Length: 9988, dtype: int64

# %%
display (data['descripcion'].head())
pd.get_dummies(data['descripcion'], drop_first=True)

data_limpia = data.join(pd.get_dummies(data['descripcion'], drop_first=True, prefix='descripcion'))

data_limpia.head()
data_limpia.drop(columns = ['lluvia','descripcion'], inplace=True)

data_limpia.head()
# Out:
# 0      Cold
# 1      Warm
# 2    Normal
# 3      Cold
# 4      Cold
# Name: descripcion, dtype: object
#    humedad  velocidad_viento_kmh  rumbo_viento_grados  visibilidad_km  \
# 0     0.92                 11.27                130.0            8.05
# 1     0.73                 20.93                330.0           16.10
# 2     0.97                  5.97                193.0           14.91
# 3     0.82                  3.22                300.0           16.10
# 4     0.60                 10.88                116.0            9.98
#
#    presion_mbar  temperatura  lluvia_binarizada  descripcion_Normal  \
# 0       1021.60        -0.56                  0                   0
# 1       1017.00        21.11                  1                   0
# 2       1013.99        16.60                  1                   1
# 3       1031.59         1.60                  1                   0
# 4       1020.88         2.19                  1                   0
#
#    descripcion_Warm
# ...

# %%
data_limpia.to_csv('data_limpia_clase9.csv')
