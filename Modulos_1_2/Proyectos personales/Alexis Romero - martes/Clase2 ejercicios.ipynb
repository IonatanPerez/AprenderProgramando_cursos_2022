# %%
#Ejercicio1

# %%
variable1=(5)
variable2=(9)

# %%
print (variable1+variable2)
# Out:
# 14

# %%
print (variable1-variable2)
# Out:
# -4

# %%
print (variable1/variable2)
# Out:
# 0.5555555555555556

# %%
print (variable1*variable2)
# Out:
# 45

# %%
#Ejercicio 2,3,4
grupo1 = ["nombre0","nombre1","nombre2"]
print (grupo1)
grupo2 = ["apellido0","apellido1","apellido2"]
print (grupo2)
grupo3=["nombre2","apellido2"]
print (grupo3)
# Out:
# ['nombre0', 'nombre1', 'nombre2']
# ['apellido0', 'apellido1', 'apellido2']
# ['nombre2', 'apellido2']

# %%
grupo1.pop(2)
print (grupo1)
grupo2.pop(2)
print (grupo2)
# Out:
# ['nombre0', 'nombre1']
# ['apellido0', 'apellido1']

# %%
todos= (grupo1+grupo2+grupo3)
print (todos)
# Out:
# ['nombre0', 'nombre1', 'apellido0', 'apellido1', 'nombre2', 'apellido2']

# %%
#Ejercicio 5,6,7,8
Diccionario={"Paises": ["argentina","chile","peru"], 
             "Capitales": ["buenos_aires","santiago","lima"]
}
print (Diccionario["Paises"])
print (Diccionario["Capitales"])
# Out:
# ['argentina', 'chile', 'peru']
# ['buenos_aires', 'santiago', 'lima']

# %%
Diccionario["Pais"]="uruguay"
print(Diccionario)
Diccionario["capital"]="montevideo"
print(Diccionario)
# Out:
# {'Paises': ['argentina', 'chile', 'peru'], 'Capitales': ['buenos_aires', 'santiago', 'lima'], 'Pais': 'uruguay'}
# {'Paises': ['argentina', 'chile', 'peru'], 'Capitales': ['buenos_aires', 'santiago', 'lima'], 'Pais': 'uruguay', 'capital': 'montevideo'}
