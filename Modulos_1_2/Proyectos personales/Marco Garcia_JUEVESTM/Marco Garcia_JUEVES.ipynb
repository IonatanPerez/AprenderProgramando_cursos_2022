# %%
#tipo_de_datos
lista_materias = ["ingles", "lengua", "matematica"]

# %%
print(lista_materias)
# Out:
# ['ingles', 'lengua', 'matematica']

# %%
lista_materias.remove("ingles")

# %%
lista_materias
# Out:
# ['lengua', 'matematica']

# %%
lista_materias.append("fisica")

# %%
lista_materias
# Out:
# ['lengua', 'matematica', 'fisica']

# %%
lista_materias[1]
# Out:
# 'matematica'

# %%
lista_materias = ["lengua","ingles","matematica"]

# %%
print(lista_materias)
# Out:
# ['lengua', 'ingles', 'matematica']

# %%
lista_materias.remove("matematica")

# %%
print(lista_materias)
# Out:
# ['lengua', 'ingles']

# %%
lista_materias.append("fisica")

# %%
print(lista_materias)
# Out:
# ['lengua', 'ingles', 'fisica']

# %%
lista_materias[1]
# Out:
# 'ingles'

# %%
materias= {"lengua": "daniela martinez", "ingles":"mariana garcia", "fisica":"manuel salgado" }

# %%
materias
# Out:
# {'fisica': 'manuel salgado',
#  'ingles': 'mariana garcia',
#  'lengua': 'daniela martinez'}

# %%
materias["termodinamica"]="marina"

# %%
print(materias)
# Out:
# {'lengua': 'daniela martinez', 'ingles': 'mariana garcia', 'fisica': 'manuel salgado', 'termodinamica': 'marina'}

# %%
materias.pop("ingles")
# Out:
# 'mariana garcia'

# %%
print(materias)
# Out:
# {'lengua': 'daniela martinez', 'fisica': 'manuel salgado', 'termodinamica': 'marina'}

# %%
#estructura_de_control

# %%
num1=1
num2=1

# %%
operacion = num1==num2

# %%
if operacion: print("es correcto")
# Out:
# es correcto

# %%
num1>num2
# Out:
# False

# %%
import pandas as pd

# %%
data= pd.read_csv("/content/dataset_total_vacunas.csv")

# %%
data
# Out:
#       FECHA_ADMINISTRACION GRUPO_ETARIO GENERO  \
# 0       29JAN2021:00:00:00      31 a 40      F
# 1       29JAN2021:00:00:00      31 a 40      F
# 2       29JAN2021:00:00:00      31 a 40      M
# 3       29JAN2021:00:00:00      31 a 40      M
# 4       29JAN2021:00:00:00      31 a 40      M
# ...                    ...          ...    ...
# 33621   22JAN2022:00:00:00      51 a 60      F
# 33622   22JAN2022:00:00:00      51 a 60      F
# 33623   22JAN2022:00:00:00      51 a 60      F
# 33624   22JAN2022:00:00:00      51 a 60      F
# 33625   22JAN2022:00:00:00      51 a 60      F
#
#                                              VACUNA      TIPO_EFECTOR  \
# 0                                           Sputnik           Público
# 1                                           Sputnik  Público nacional
# 2                                           Sputnik           Privado
# 3                                           Sputnik           Público
# ...

# %%
display(data. tail(4))
# Out:
#       FECHA_ADMINISTRACION GRUPO_ETARIO GENERO  \
# 33622   22JAN2022:00:00:00      51 a 60      F
# 33623   22JAN2022:00:00:00      51 a 60      F
# 33624   22JAN2022:00:00:00      51 a 60      F
# 33625   22JAN2022:00:00:00      51 a 60      F
#
#                                              VACUNA TIPO_EFECTOR  DOSIS_1  \
# 33622                                       Moderna      Público        1
# 33623                                     Sinopharm      Público       27
# 33624                                       Sputnik      Público        0
# 33625  vacuna Coronavirus (CANSINO), vial x 1 dosis      Público        1
#
#        DOSIS_2  ID_CARGA  DOSIS_3
# 33622        0       NaN    298.0
# 33623       10       NaN      1.0
# 33624        4       NaN      0.0
# 33625        0       NaN      0.0
