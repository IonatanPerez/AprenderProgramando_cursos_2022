# %% [markdown]
# Seguimos con lo que habia quedado de la clase pasada.

# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("/content/Dataset Clima.csv")
data.head()
# Out:
#    id  Humidity  Wind_Speed_kmh  rumbo_viento_grados  visibilidad_km  \
# 0   0      0.92           11.27                130.0            8.05
# 1   1      0.73           20.93                330.0           16.10
# 2   2      0.97            5.97                193.0           14.91
# 3   3      0.82            3.22                300.0           16.10
# 4   4      0.60           10.88                116.0            9.98
#
#    presion_mbar lluvia descripcion  temperatura
# 0       1021.60     no        Cold        -0.56
# 1       1017.00     si        Warm        21.11
# 2       1013.99     si      Normal        16.60
# 3       1031.59     si        Cold         1.60
# 4       1020.88     si        Cold         2.19

# %%
data.isna().sum()
# Out:
# id                     0
# Humidity               5
# Wind_Speed_kmh         5
# rumbo_viento_grados    5
# visibilidad_km         5
# presion_mbar           9
# lluvia                 1
# descripcion            8
# temperatura            0
# dtype: int64

# %%
data.dtypes
# Out:
# id                       int64
# Humidity               float64
# Wind_Speed_kmh         float64
# rumbo_viento_grados    float64
# visibilidad_km         float64
# presion_mbar           float64
# lluvia                  object
# descripcion             object
# temperatura            float64
# dtype: object

# %%
data.describe()
# Out:
#                 id     Humidity  Wind_Speed_kmh  rumbo_viento_grados  \
# count  10000.00000  9995.000000     9995.000000          9995.000000
# mean    4999.50000     0.735334       10.813809           185.947274
# std     2886.89568     0.195459        6.972945           107.477976
# min        0.00000     0.000000        0.000000             0.000000
# 25%     2499.75000     0.600000        5.750000           112.000000
# 50%     4999.50000     0.780000        9.930000           179.000000
# 75%     7499.25000     0.900000       14.100000           290.000000
# max     9999.00000     1.000000       53.240000           359.000000
#
#        visibilidad_km  presion_mbar   temperatura
# count     9995.000000   9991.000000  10000.000000
# mean        10.372852   1004.884407     11.857190
# std          4.179357    109.665639      9.512215
# min          0.000000      0.000000    -21.820000
# 25%          8.285000   1011.890000      4.660000
# ...

# %%
data.columns
# Out:
# Index(['id', 'Humidity', 'Wind_Speed_kmh', 'rumbo_viento_grados',
#        'visibilidad_km', 'presion_mbar', 'lluvia', 'descripcion',
#        'temperatura'],
#       dtype='object')

# %%
cambio_nombres = {"Humidity":"humedad_relativa","Wind_Speed_kmh":"velocidad_viento_kmh"}
data.rename(columns=cambio_nombres, inplace=True)

# %%
data.head()
# Out:
#    id  humedad_relativa  velocidad_viento_kmh  rumbo_viento_grados  \
# 0   0              0.92                 11.27                130.0
# 1   1              0.73                 20.93                330.0
# 2   2              0.97                  5.97                193.0
# 3   3              0.82                  3.22                300.0
# 4   4              0.60                 10.88                116.0
#
#    visibilidad_km  presion_mbar lluvia descripcion  temperatura
# 0            8.05       1021.60     no        Cold        -0.56
# 1           16.10       1017.00     si        Warm        21.11
# 2           14.91       1013.99     si      Normal        16.60
# 3           16.10       1031.59     si        Cold         1.60
# 4            9.98       1020.88     si        Cold         2.19

# %%
data.corr()
# Out:
#                             id  humedad_relativa  velocidad_viento_kmh  \
# id                    1.000000          0.005614             -0.012223
# humedad_relativa      0.005614          1.000000             -0.222691
# velocidad_viento_kmh -0.012223         -0.222691              1.000000
# rumbo_viento_grados  -0.012235         -0.007590              0.108552
# visibilidad_km       -0.003619         -0.375662              0.100517
# presion_mbar          0.001109         -0.011142             -0.051101
# temperatura          -0.006969         -0.628784              0.009679
#
#                       rumbo_viento_grados  visibilidad_km  presion_mbar  \
# id                              -0.012235       -0.003619      0.001109
# humedad_relativa                -0.007590       -0.375662     -0.011142
# velocidad_viento_kmh             0.108552        0.100517     -0.051101
# rumbo_viento_grados              1.000000        0.052067     -0.005622
# ...

# %%
sns.heatmap(data.corr(), annot=True)

# %%
sns.displot(data["temperatura"])

# %%
sns.displot(data['rumbo_viento_grados'])

# %%
sns.displot(data["velocidad_viento_kmh"])

# %%
data.drop(columns='id', inplace=True)
data.head()
# Out:
#    humedad_relativa  velocidad_viento_kmh  rumbo_viento_grados  \
# 0              0.92                 11.27                130.0
# 1              0.73                 20.93                330.0
# 2              0.97                  5.97                193.0
# 3              0.82                  3.22                300.0
# 4              0.60                 10.88                116.0
#
#    visibilidad_km  presion_mbar lluvia descripcion  temperatura
# 0            8.05       1021.60     no        Cold        -0.56
# 1           16.10       1017.00     si        Warm        21.11
# 2           14.91       1013.99     si      Normal        16.60
# 3           16.10       1031.59     si        Cold         1.60
# 4            9.98       1020.88     si        Cold         2.19

# %%
data['lluvia']
# Out:
# 0       no
# 1       si
# 2       si
# 3       si
# 4       si
#         ..
# 9995    si
# 9996    si
# 9997    si
# 9998    si
# 9999    si
# Name: lluvia, Length: 10000, dtype: object

# %%
data['lluvia'].unique()
# Out:
# array(['no', 'si', nan], dtype=object)

# %%
data['lluvia'].value_counts()
# Out:
# si    8911
# no    1088
# Name: lluvia, dtype: int64

# %%
sns.countplot(data['descripcion'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
data.to_csv('/content/data_clima_post_clase_1.csv')
