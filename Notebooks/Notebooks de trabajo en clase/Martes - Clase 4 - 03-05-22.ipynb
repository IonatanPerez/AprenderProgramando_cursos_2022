# %% [markdown]
# Hoy vamos a arrancar con herramientas mas especificas de ciencia de datos.

# %%
import mi_funcion

# %%
mi_funcion.hola()
# Out:
# Hola Juan

# %%
import math

# %%
math.factorial(4)
# Out:
# 24

# %%
import pandas as pd
