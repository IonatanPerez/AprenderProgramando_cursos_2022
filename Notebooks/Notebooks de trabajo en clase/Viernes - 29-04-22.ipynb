# %%
mi_variable = 4

print ("Escribime un ´hola´")
escrito = input()

if escrito == "hola":
  print ("Bien! sos obediente!")
else:
  print ("Haceme caso!")
  print ("gracias!")
# Out:
# Escribime un ´hola´
# hola
# Bien! sos obediente!

# %%
mi_lista = [1,4,2,68,12,23,43,22]

numero = mi_lista[0]
if numero%2 == 0:
  print (numero, "es par")
else:
  print (numero, "es impar")


numero = mi_lista[1]
if numero%2 == 0:
  print (numero, "es par")
else:
  print (numero, "es impar")


numero = mi_lista[2]
if numero%2 == 0:
  print (numero, "es par")
else:
  print (numero, "es impar")


numero = mi_lista[3]
if numero%2 == 0:
  print (numero, "es par")
else:
  print (numero, "es impar")


numero = mi_lista[4]
if numero%2 == 0:
  print (numero, "es par")
else:
  print (numero, "es impar")



numero = mi_lista[5]
if numero%2 == 0:
  print (numero, "es par")
else:
  print (numero, "es impar")



numero = mi_lista[6]
if numero%2 == 0:
  print (numero, "es par")
else:
  print (numero, "es impar")
# Out:
# 1 es impar
# 4 es par
# 2 es par
# 68 es par
# 12 es par
# 23 es impar
# 43 es impar

# %%
lista1 = [1,3,5,7]
lista2 = [2,4,6,5,8]

for numero in mi_lista:
  indicar_si_es_par(numero)
for numero in lista1:
  indicar_si_es_par(numero)
for numero in lista2:
  indicar_si_es_par(numero)

print (aa)
# Out:
# hola
# 1 es impar
# hola
# 4 es par
# hola
# 2 es par
# hola
# 68 es par
# hola
# 12 es par
# hola
# 23 es impar
# hola
# 43 es impar
# hola
# 22 es par
# hola
# 1 es impar
# hola
# 3 es impar
# hola
# 5 es impar
# hola
# 7 es impar
# hola
# 2 es par
# hola
# 4 es par
# hola
# 6 es par
# hola
# 5 es impar
# hola
# 8 es par
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-4b579ff78fae> in <module>()
#       9   indicar_si_es_par(numero)
#      10
# ---> 11 print (aa)
#
# NameError: name 'aa' is not defined

# %%
def indicar_si_es_par(numero_que_recibo):
    aa = "hola"
    print (aa)
    if numero_que_recibo%2 == 0:
      print (numero_que_recibo, "es par")
    else:
      print (numero_que_recibo, "es impar")

# %%
for numero in mi_lista:
  print ("Hola")
  print (numero)
# Out:
# Hola
# 1
# Hola
# 4
# Hola
# 2
# Hola
# 68
# Hola
# 12
# Hola
# 23
# Hola
# 43
# Hola
# 22
