# %%
lista_de_materias = ["Matematica", "Redes"]
mi_nombre = "Ioni"

# %%
lista_de_materias
otra_cosa = mi_nombre

# %%
display (lista_de_materias)
# Out:
# ['Matematica', 'Redes']

# %%
profes_por_materia = {"Matematica":"Vanesa", "Fisica":"Mirta", "Sistemas de control":"Mallol"}

# %%
profes_por_materia.popitem()
# Out:
# ('Fisica', 'Mirta')

# %%
profes_por_materia["Matematica"] = "Vanesa"

# %%
profes_por_materia.pop("Matematica")
# Out:
# 'Vanesa'

# %%
print (profes_por_materia)
# Out:
# {}

# %%
mi_numero = 15

mi_otro_numero = float(input())

print (mi_numero == mi_otro_numero)

if mi_numero == mi_otro_numero:
  print ("El primer numero es: " + str(mi_numero))
  print ("El segundo numero es: " + str(mi_otro_numero))
  print ("Los numeros son iguales")
else:
  print ("Los numeros no son iguales.")
print ("Los numeros no son iguales.")
# Out:
# 15
# True
# El primer numero es: 15
# El segundo numero es: 15.0
# Los numeros son iguales
# Los numeros no son iguales.

# %%
no_llueve = False

if no_llueve:
  print ("Vamos a la plaza")
else:
  print ("Nos quedamos")
# Out:
# Nos quedamos

# %%
range(10)
# Out:
# range(0, 10)

# %%
for elemento in range(10):
  print (elemento*5)
# Out:
# 0
# 5
# 10
# 15
# 20
# 25
# 30
# 35
# 40
# 45

# %%
for cosa in profes_por_materia.items():
  print ("El/la profe de " + cosa[0] + " se llama " + cosa[1])
# Out:
# El/la profe de Matematica se llama Vanesa
# El/la profe de Fisica se llama Mirta
# El/la profe de Sistemas de control se llama Mallol

# %%
print ("Escribi el numero del que queres la tabla")
numero = int(input())

# %%
def tabla_de_numero(numero):
  for elemento in range(10):
    print (elemento*numero)

# %%
def division(numerador,denominador):
  return numerador/denominador

# %%
resultado = division(3,0.0000001)
print (resultado)
print (float("inf")+1000000)
# Out:
# 30000000.0
# inf

# %%
tabla_de_numero(8)
# Out:
# 0
# 8
# 16
# 24
# 32
# 40
# 48
# 56
# 64
# 72

# %% [markdown]
# # Vamos a arrancar con Pandas

# %%
import pandas as pd

# %%
data = pd.read_csv("Encuentros educación ambiental.csv", sep=";")

# %%
data.shape
data.columns

data["columna sin sentido"] = data["encuentro_anio"] /3
data["columna sin sentido"].value_counts()
# Out:
# 672.333333    5
# 672.666667    4
# 673.000000    4
# 672.000000    3
# Name: columna sin sentido, dtype: int64

# %%
display (data)
# Out:
#     encuentro_anio  encuentro_numero  encuentro_participantes  \
# 0             2016                 1                       90
# 1             2016                 1                       90
# 2             2016                 1                      400
# 3             2017                 4                      250
# 4             2017                 2                     3000
# 5             2017                 2                      130
# 6             2017                 1                       22
# 7             2017                 1                      700
# 8             2018                 8                      540
# 9             2018                 2                      150
# 10            2018                10                      350
# 11            2018                 1                      170
# 12            2019                 1                      220
# 13            2019                 2                       20
# ...

# %%
data
# Out:
#     encuentro_anio  encuentro_numero  encuentro_participantes  \
# 11            2018                 1                      170
# 12            2019                 1                      220
# 13            2019                 2                       20
# 14            2019                 2                       50
# 15            2019                 7                       80
#
#                                    encuentro_tematica  \
# 11  Encuentro de Educación Ambiental y Exóticas In...
# 12                           Encuentro Nacional de EA
# 13  Estrategia Nacional de EA/Encuentros provincia...
# 14  Estrategia Nacional para la Sustentabilidad en...
# 15  Mesa intraministerial de gènero ambiente y des...
#
#                               Encuentro_destinatarios
# 11  Funcionarios, educadores, periodistas, cientìf...
# 12  Funcionarios de los Ministerios de Ambiente y ...
# 13   Funcionarios provinciales de Educaciòn Ambiental
# ...
