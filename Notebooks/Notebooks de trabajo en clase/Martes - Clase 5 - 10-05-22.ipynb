# %%
import mi_funcion

# %%
mi_funcion.hola(mi_funcion.nombre_del_curso)
# Out:
# Hola los cientificos

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(10)
# Out:
# 3.1622776601683795

# %%
import pandas as pd

# %%
data = pd.read_csv("encuesta.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['Año de cursada', 'Edad', 'Zona de residencia',
#        'Conocimientos previos de programacion', 'Como me entere del curso',
#        'Nacionalidad', 'Promedio en matematica', 'Promedio en lengua',
#        'Promedio total', 'Escuela Tecnica (Si/No)', 'Bachiller (Si/No)',
#        'Genero', 'Mascotas', 'Uso de tecnologia', 'Gamer', 'Trabaja'],
#       dtype='object')

# %%
data["Edad"].value_counts()
# Out:
# 17.0    10
# 16.0     6
# 18.0     3
# Name: Edad, dtype: int64

# %%
data["Edad"].hist()

# %%
# Es lo mismo

data.Edad.hist()

# %%
for columna in data.columns:
  print("La columna " + columna + " tiene un valor promedio: " + data[columna].mean())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1602         try:
# -> 1603             x = float(x)
#    1604         except (TypeError, ValueError):
#
# ValueError: could not convert string to float: '4to año4° año4° año4to año5to Año5° Año6to año5° año5to6to4to5to año5to año5to año5to5to año5to4to año 4to año5to '
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1606             try:
# -> 1607                 x = complex(x)
#    1608             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
for columna in data.columns:
  print (data[columna].dtype)
# Out:
# object
# float64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object

# %%
data[["Edad","Mascotas"]]
# Out:
#     Edad               Mascotas
# 0   17.0                Un gato
# 1   16.0               un perro
# 2    NaN                    NaN
# 3   16.0                     No
# 4   17.0   Dos gatos y un perro
# 5   17.0                Ninguna
# 6   18.0                un gato
# 7   17.0                Ninguna
# 8   18.0               2 perras
# 9   17.0                      0
# 10  16.0               un perro
# 11  17.0                 1 gato
# 12  18.0               un perro
# 13  16.0   dos perros y un gato
# 14  17.0                Un gato
# 15  17.0               2 perros
# 16  17.0     4 perros y un gato
# 17  16.0               ninguna
# 18  16.0                1 gato
# 19  17.0                Un gato

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 16 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Año de cursada                         20 non-null     object
#  1   Edad                                   19 non-null     float64
#  2   Zona de residencia                     19 non-null     object
#  3   Conocimientos previos de programacion  19 non-null     object
#  4   Como me entere del curso               19 non-null     object
#  5   Nacionalidad                           19 non-null     object
#  6   Promedio en matematica                 18 non-null     object
#  7   Promedio en lengua                     18 non-null     object
#  8   Promedio total                         18 non-null     object
#  9   Escuela Tecnica (Si/No)                18 non-null     object
# ...

# %%
data["Trabaja"]
# Out:
# 0      No
# 1      no
# 2     NaN
# 3      No
# 4     NaN
# 5      No
# 6      no
# 7      no
# 8      No
# 9      SI
# 10     no
# 11    NaN
# 12    no
# 13    no
# 14     No
# 15     no
# 16     no
# 17    No
# 18    NaN
# 19     No
# Name: Trabaja, dtype: object

# %%
data["Nacionalidad"].unique()
# Out:
# array(['Paraguaya', 'argentino', nan, 'Venezuela', 'Argentina',
#        'Argentino', 'Venezolana', 'argentina'], dtype=object)

# %%
renombrar = {"Conocimientos previos de programacion":"programación"}
data.rename(columns = renombrar, inplace=True)

# %%
data.head()
# Out:
#        Año  Edad Zona de residencia             programación  \
# 0  4to año  17.0           Barracas          Python - Basico
# 1   4° año  16.0           barracas  javascript-basico, html
# 2   4° año   NaN                NaN                      NaN
# 3  4to año  16.0           Recoleta                  Ninguno
# 4  5to Año  17.0     San Cristóbal                   Ninguno
#
#   Como me entere del curso Nacionalidad  Promedio en matematica  \
# 0            En la escuela    Paraguaya                     9.0
# 1            en la escuela    argentino                     8.0
# 2                      NaN          NaN                     NaN
# 3                  Escuela    Venezuela  Bien en lo que me dan¿
# 4          Por un conocido    Argentina                     NaN
#
#   Promedio en lengua Promedio total Escuela Tecnica (Si/No) Bachiller (Si/No)  \
# 0                8.0            8.5                      Si                no
# ...

# %% [markdown]
# # Clase 5
#
# Hasta aca fue repaso de la clase 4 ahora arrancamos con la clase 5

# %%
data.head()
# Out:
#        Año  Edad Zona de residencia             programación  \
# 0  4to año  17.0           Barracas          Python - Basico
# 1   4° año  16.0           barracas  javascript-basico, html
# 2   4° año   NaN                NaN                      NaN
# 3  4to año  16.0           Recoleta                  Ninguno
# 4  5to Año  17.0     San Cristóbal                   Ninguno
#
#   Como me entere del curso Nacionalidad  Promedio en matematica  \
# 0            En la escuela    Paraguaya                     9.0
# 1            en la escuela    argentino                     8.0
# 2                      NaN          NaN                     NaN
# 3                  Escuela    Venezuela  Bien en lo que me dan¿
# 4          Por un conocido    Argentina                     NaN
#
#   Promedio en lengua Promedio total Escuela Tecnica (Si/No) Bachiller (Si/No)  \
# 0                8.0            8.5                      Si                no
# ...

# %%
# Como seleccionar algunas filas
data.iloc[:10]
# Out:
#        Año  Edad     Zona de residencia  \
# 0  4to año  17.0               Barracas
# 1   4° año  16.0               barracas
# 2   4° año   NaN                    NaN
# 3  4to año  16.0               Recoleta
# 4  5to Año  17.0         San Cristóbal
# 5   5° Año  17.0  General de San martin
# 6  6to año  18.0                   CABA
# 7   5° año  17.0                  Lanús
# 8      5to  18.0        Lomas de Zamora
# 9      6to  17.0       villa ballester
#
#                                         programación  \
# 0                                    Python - Basico
# 1                            javascript-basico, html
# 2                                                NaN
# 3                                            Ninguno
# 4                                            Ninguno
# 5                              Python, Java - Basico
# 6                                           css.java
# 7  HTML,css, javascript,java,php, Python,react,c+...
# ...

# %%
palabra = "dinosaurio"
palabra[::2]
# Out:
# 'dnsui'

# %%
data_modificada = data.set_index("Zona de residencia")

# %%
data_modificada.head()
# Out:
#                         Año  Edad             programación  \
# Zona de residencia
# Barracas            4to año  17.0          Python - Basico
# barracas             4° año  16.0  javascript-basico, html
# NaN                  4° año   NaN                      NaN
# Recoleta            4to año  16.0                  Ninguno
# San Cristóbal       5to Año  17.0                  Ninguno
#
#                    Como me entere del curso Nacionalidad  \
# Zona de residencia
# Barracas                      En la escuela    Paraguaya
# barracas                      en la escuela    argentino
# NaN                                     NaN          NaN
# Recoleta                            Escuela    Venezuela
# San Cristóbal               Por un conocido    Argentina
#
#                     Promedio en matematica Promedio en lengua Promedio total  \
# Zona de residencia
# Barracas                               9.0                8.0            8.5
# ...

# %%
data["Zona de residencia"].value_counts()
# Out:
# CABA                     3
# Barracas                 2
# barracas                 1
# Recoleta                 1
# San Cristóbal            1
# General de San martin    1
# Lanús                    1
# Lomas de Zamora          1
# villa ballester          1
# Palermo(CABA)            1
# San Telmo                1
# La paternal (CABA)       1
# Nueva Pompeya            1
# CABA                     1
# colegiales               1
# Flores  (CABA)           1
# Name: Zona de residencia, dtype: int64

# %%
data_modificada.loc["General de San martin"]
# Out:
# Año                                        5° Año
# Edad                                         17.0
# programación                Python, Java - Basico
# Como me entere del curso            En la escuela
# Nacionalidad                            Argentino
# Promedio en matematica                        9,5
# Promedio en lengua                            6.0
# Promedio total                                7.0
# Escuela Tecnica (Si/No)                        Si
# Bachiller (Si/No)                              No
# Genero                                  masculino
# Mascotas                                  Ninguna
# Uso de tecnologia                              Si
# Gamer                                          Si
# Trabaja                                        No
# Name: General de San martin, dtype: object

# %%
data.head()
mascara = data["Edad"] == 16
mascara
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19    False
# Name: Edad, dtype: bool

# %%
data.loc[mascara]
# Out:
#          Año  Edad Zona de residencia                            programación  \
# 1     4° año  16.0           barracas                 javascript-basico, html
# 3    4to año  16.0           Recoleta                                 Ninguno
# 10       4to  16.0      Palermo(CABA)  fundamentos de codificacion JavaScript
# 13   5to año  16.0               CABA                         javascript,html
# 17  4to año   16.0         colegiales                                ninguno
# 18   4to año  16.0           Barracas                  ninguno por el momento
#
#           Como me entere del curso Nacionalidad  Promedio en matematica  \
# 1                    en la escuela    argentino                     8.0
# 3                          Escuela    Venezuela  Bien en lo que me dan¿
# 10                   En la escuela    Argentina                       6
# 13             me llego un correo     Argentina                       6
# ...

# %%
data[data["Edad"]==17]
# Out:
#         Año  Edad     Zona de residencia  \
# 0   4to año  17.0               Barracas
# 4   5to Año  17.0         San Cristóbal
# 5    5° Año  17.0  General de San martin
# 7    5° año  17.0                  Lanús
# 9       6to  17.0       villa ballester
# 11  5to año  17.0              San Telmo
# 14      5to  17.0          Nueva Pompeya
# 15  5to año  17.0                  CABA
# 16      5to  17.0                   CABA
# 19     5to   17.0         Flores  (CABA)
#
#                                          programación  \
# 0                                     Python - Basico
# 4                                             Ninguno
# 5                               Python, Java - Basico
# 7   HTML,css, javascript,java,php, Python,react,c+...
# 9                   HTML,CSS,javascript,node y React.
# 11                                         C++ básico
# 14                            JavaScript básico, Java
# 15                                            ninguno
# ...

# %%
data_agrupada = data.groupby("Edad")

# %%
data_agrupada.size()
# Out:
# Edad
# 16.0     6
# 17.0    10
# 18.0     3
# dtype: int64

# %%
data_agrupada["Genero"].value_counts()
# Out:
# Edad  Genero
# 16.0  Femenino      2
#       Masculino     2
#       Masculino     1
#       hombre        1
# 17.0  Femenino      2
#       masculino     2
#       FEmenino      1
#       Femenino      1
#       Masculino     1
#       femenino      1
#       femenino      1
#       hombre        1
# 18.0  masculino     2
#       Masculino     1
# Name: Genero, dtype: int64
